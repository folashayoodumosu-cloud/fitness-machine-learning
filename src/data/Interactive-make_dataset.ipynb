# %% [markdown]
# Connected to Python 3.11.3

# %%
import pandas as pd

# %%
import numpy as np

# %%
mport pandas as pd
from glob import glob
# Out:
#   Cell In[3], line 1
#     mport pandas as pd
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from glob import glob

# %%
from glob import glob

# %%
single_file_acc = pd.read_csv("../../data/raw/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv")

# %%
single_file_acc = pd.read_csv("../../data/raw/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv")

# %%
single_file_acc
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547219408431  2019-01-11T16:10:08.431         0.00       0.010
# 1    1547219408511  2019-01-11T16:10:08.511         0.08       0.000
# 2    1547219408591  2019-01-11T16:10:08.591         0.16       0.001
# 3    1547219408671  2019-01-11T16:10:08.671         0.24      -0.012
# 4    1547219408751  2019-01-11T16:10:08.751         0.32      -0.013
# ..             ...                      ...          ...         ...
# 201  1547219424511  2019-01-11T16:10:24.511        16.08       0.027
# 202  1547219424591  2019-01-11T16:10:24.591        16.16       0.010
# 203  1547219424671  2019-01-11T16:10:24.671        16.24       0.011
# 204  1547219424751  2019-01-11T16:10:24.751        16.32       0.008
# 205  1547219424831  2019-01-11T16:10:24.831        16.40       0.021
#
#      y-axis (g)  z-axis (g)
# 0         0.964      -0.087
# 1         0.961      -0.069
# 2         0.974      -0.087
# 3         0.971      -0.084
# 4         0.954      -0.094
# ..          ...         ...
# 201       0.970      -0.091
# 202       0.990      -0.068
# 203       0.978      -0.091
# 204       0.937      -0.085
# 205       0.966      -0.108
#
# [206 rows x 6 columns]

# %%
single_file_gyro = pd.read_csv("../../data/raw/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv")

# %%
single_file_gyro
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0    1547219408351  2019-01-11T16:10:08.351         0.00           0.122
# 1    1547219408391  2019-01-11T16:10:08.391         0.04           2.195
# 2    1547219408431  2019-01-11T16:10:08.431         0.08           2.622
# 3    1547219408471  2019-01-11T16:10:08.471         0.12           1.951
# 4    1547219408511  2019-01-11T16:10:08.511         0.16           1.524
# ..             ...                      ...          ...             ...
# 409  1547219424711  2019-01-11T16:10:24.711        16.36           2.195
# 410  1547219424751  2019-01-11T16:10:24.751        16.40           4.451
# 411  1547219424791  2019-01-11T16:10:24.791        16.44           7.195
# 412  1547219424831  2019-01-11T16:10:24.831        16.48           8.963
# 413  1547219424871  2019-01-11T16:10:24.871        16.52          -3.476
#
#      y-axis (deg/s)  z-axis (deg/s)
# 0            -5.488          -3.841
# 1            -9.695          -0.610
# 2            -8.110          -4.024
# 3            -4.695          -4.634
# 4            -2.561          -2.500
# ..              ...             ...
# 409          -1.402           4.268
# 410          -1.220           0.244
# 411          -4.329           6.524
# 412          -1.037          -0.366
# 413           2.134          -5.305
#
# [414 rows x 6 columns]

# %%
files = glob("../../data/raw/MetaMotion/*.csv")

# %%
glob
# Out:
# <function glob.glob(pathname, *, root_dir=None, dir_fd=None, recursive=False, include_hidden=False)>

# %%
files
# Out:
# ['../../data/raw/MetaMotion\\A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.38.54.580_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.38.54.580_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.41.24.439_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.41.24.439_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy3-rpe7_MetaWear_2019-01-11T16.44.00.801_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy3-rpe7_MetaWear_2019-01-11T16.44.00.801_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium1-rpe7_MetaWear_2019-01-11T16.53.53.376_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium1-rpe7_MetaWear_2019-01-11T16.53.53.376_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium2-rpe7_MetaWear_2019-01-11T16.57.30.113_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium2-rpe7_MetaWear_2019-01-11T16.57.30.113_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium3-rpe7_MetaWear_2019-01-11T17.00.49.801_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium3-rpe7_MetaWear_2019-01-11T17.00.49.801_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.04.08.637_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.04.08.637_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium1-rpe7_MetaWear_2019-01-11T17.05.44.498_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium1-rpe7_MetaWear_2019-01-11T17.05.44.498_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium2-rpe8_MetaWear_2019-01-11T17.17.15.443_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium2-rpe8_MetaWear_2019-01-11T17.17.15.443_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium3-rpe7_MetaWear_2019-01-11T17.19.34.896_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium3-rpe7_MetaWear_2019-01-11T17.19.34.896_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy1-rpe8_MetaWear_2019-01-11T16.08.04.758_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy1-rpe8_MetaWear_2019-01-11T16.08.04.758_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy2-rpe8_MetaWear_2019-01-11T16.12.04.794_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy2-rpe8_MetaWear_2019-01-11T16.12.04.794_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.40.07.902_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.40.07.902_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.42.43.398_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.42.43.398_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy3-rpe8_MetaWear_2019-01-11T16.45.55.708_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy3-rpe8_MetaWear_2019-01-11T16.45.55.708_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium1-rpe8_MetaWear_2019-01-11T16.48.54.290_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium1-rpe8_MetaWear_2019-01-11T16.48.54.290_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium2-rpe8_MetaWear_2019-01-11T16.55.53.154_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium2-rpe8_MetaWear_2019-01-11T16.55.53.154_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium3-rpe9_MetaWear_2019-01-11T16.59.28.181_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium3-rpe9_MetaWear_2019-01-11T16.59.28.181_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-squat-medium1-rpe9_MetaWear_2019-01-11T17.09.32.694_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-squat-medium1-rpe9_MetaWear_2019-01-11T17.09.32.694_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy1_MetaWear_2019-01-14T14.29.37.418_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy1_MetaWear_2019-01-14T14.29.37.418_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy2_MetaWear_2019-01-14T14.32.11.392_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy2_MetaWear_2019-01-14T14.32.11.392_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy_MetaWear_2019-01-14T14.51.27.130_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy_MetaWear_2019-01-14T14.51.27.130_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.28.15.269_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.28.15.269_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.32.32.136_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.32.32.136_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.37.17.794_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.37.17.794_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.54.34.321_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.54.34.321_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.57.26.702_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.57.26.702_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.06.31.280_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.06.31.280_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.11.55.634_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.11.55.634_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.17.27.856_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.17.27.856_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-heavy_MetaWear_2019-01-18T18.03.51.096_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-heavy_MetaWear_2019-01-18T18.03.51.096_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.45.47.575_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.45.47.575_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.51.40.910_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.51.40.910_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv']

# %%
len(files)
# Out:
# 187

# %%
files[0]
# Out:
# '../../data/raw/MetaMotion\\A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'

# %%
participant = f.split("-")[0].replace(data_path, "")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 participant = f.split("-")[0].replace(data_path, "")
#
# NameError: name 'f' is not defined

# %%
data_path = "../../data/raw/MetaMotion/"

# %%
f = files[0]

# %%
participant = f.split("-")[0].replace(data_path, "")

# %%
lens = f.split("-")[1]

# %%
category = f.split("-")[2].rstrip("123")

# %%
df = pd.read_csv(f)

# %%
df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547219408431  2019-01-11T16:10:08.431         0.00       0.010
# 1    1547219408511  2019-01-11T16:10:08.511         0.08       0.000
# 2    1547219408591  2019-01-11T16:10:08.591         0.16       0.001
# 3    1547219408671  2019-01-11T16:10:08.671         0.24      -0.012
# 4    1547219408751  2019-01-11T16:10:08.751         0.32      -0.013
# ..             ...                      ...          ...         ...
# 201  1547219424511  2019-01-11T16:10:24.511        16.08       0.027
# 202  1547219424591  2019-01-11T16:10:24.591        16.16       0.010
# 203  1547219424671  2019-01-11T16:10:24.671        16.24       0.011
# 204  1547219424751  2019-01-11T16:10:24.751        16.32       0.008
# 205  1547219424831  2019-01-11T16:10:24.831        16.40       0.021
#
#      y-axis (g)  z-axis (g)
# 0         0.964      -0.087
# 1         0.961      -0.069
# 2         0.974      -0.087
# 3         0.971      -0.084
# 4         0.954      -0.094
# ..          ...         ...
# 201       0.970      -0.091
# 202       0.990      -0.068
# 203       0.978      -0.091
# 204       0.937      -0.085
# 205       0.966      -0.108
#
# [206 rows x 6 columns]

# %%
df["participant"] = participant

# %%
df["lens"] = lens

# %%
df["category"] = category

# %%
participant
# Out:
# '../../data/raw/MetaMotion\\A'

# %%
df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547219408431  2019-01-11T16:10:08.431         0.00       0.010
# 1    1547219408511  2019-01-11T16:10:08.511         0.08       0.000
# 2    1547219408591  2019-01-11T16:10:08.591         0.16       0.001
# 3    1547219408671  2019-01-11T16:10:08.671         0.24      -0.012
# 4    1547219408751  2019-01-11T16:10:08.751         0.32      -0.013
# ..             ...                      ...          ...         ...
# 201  1547219424511  2019-01-11T16:10:24.511        16.08       0.027
# 202  1547219424591  2019-01-11T16:10:24.591        16.16       0.010
# 203  1547219424671  2019-01-11T16:10:24.671        16.24       0.011
# 204  1547219424751  2019-01-11T16:10:24.751        16.32       0.008
# 205  1547219424831  2019-01-11T16:10:24.831        16.40       0.021
#
#      y-axis (g)  z-axis (g)                  participant   lens category
# 0         0.964      -0.087  ../../data/raw/MetaMotion\A  bench    heavy
# 1         0.961      -0.069  ../../data/raw/MetaMotion\A  bench    heavy
# 2         0.974      -0.087  ../../data/raw/MetaMotion\A  bench    heavy
# 3         0.971      -0.084  ../../data/raw/MetaMotion\A  bench    heavy
# 4         0.954      -0.094  ../../data/raw/MetaMotion\A  bench    heavy
# ..          ...         ...                          ...    ...      ...
# 201       0.970      -0.091  ../../data/raw/MetaMotion\A  bench    heavy
# 202       0.990      -0.068  ../../data/raw/MetaMotion\A  bench    heavy
# 203       0.978      -0.091  ../../data/raw/MetaMotion\A  bench    heavy
# 204       0.937      -0.085  ../../data/raw/MetaMotion\A  bench    heavy
# 205       0.966      -0.108  ../../data/raw/MetaMotion\A  bench    heavy
#
# [206 rows x 9 columns]

# %%
participant
# Out:
# '../../data/raw/MetaMotion\\A'

# %%
lens
# Out:
# 'bench'

# %%
category
# Out:
# 'heavy'

# %%
acc_df = pd.DataFrame()

# %%
gyr_df = pd.DataFrame()

# %%
acc_set = 1

# %%
gyr_set = 1

# %%
for f in files:
    participant = f.split("-")[0].replace(data_path, "")
    lens = f.split("-")[1]
    category = f.split("-")[2].rstrip("123")

# %%
print(label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 print(label)
#
# NameError: name 'label' is not defined

# %%
for f in files:
# Out:
#   Cell In[38], line 1
#     for f in files:
#                    ^
# SyntaxError: incomplete input

# %%
participant = f.split("-")[0].replace(data_path, "")

# %%
lens = f.split("-")[1]

# %%
category = f.split("-")[2].rstrip("123")

# %%
print(label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print(label)
#
# NameError: name 'label' is not defined

# %%
label = f.split("-")[1]

# %%
df["label"] = label

# %%
print(participant)
# Out:
# ../../data/raw/MetaMotion\E

# %%
print(label)
# Out:
# squat

# %%
print(participant)
# Out:
# ../../data/raw/MetaMotion\E

# %%
print(category)
# Out:
# heavy_MetaWear_2019

# %%
ata_path = "../../data/raw/MetaMotion/"
f = files[1]

participant = f.split("-")[0].replace(data_path, "")
label = f.split("-")[1]
category = f.split("-")[2].rstrip("123")

df = pd.read_csv(f)

df["participant"] = participant
df["label"] = label       
df["category"] = category

# --------------------------------------------------------------
# Read all files
# --------------------------------------------------------------

acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1
gyr_set = 1

for f in files:
    participant = f.split("-")[0].replace(data_path, "")
    lens = f.split("-")[1]
    category = f.split("-")[2].rstrip("123")
    
    print(category)
# Out:
# heavy
# heavy
# heavy2_MetaWear_2019
# heavy2_MetaWear_2019
# heavy
# heavy
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium
# medium
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium
# medium
# medium
# medium
# medium
# medium
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# heavy1_MetaWear_2019
# heavy1_MetaWear_2019
# heavy2_MetaWear_2019
# heavy2_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy
# heavy
# heavy2_MetaWear_2019
# heavy2_MetaWear_2019
# heavy
# heavy
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium
# medium
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019

# %%
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

# %%
data_path = "../../data/raw/MetaMotion/"
f = files[1]

participant = f.split("-")[0].replace(data_path, "")
label = f.split("-")[1]
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

df = pd.read_csv(f)

df["participant"] = participant
df["label"] = label       
df["category"] = category

# --------------------------------------------------------------
# Read all files
# --------------------------------------------------------------

acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1
gyr_set = 1

for f in files:
    participant = f.split("-")[0].replace(data_path, "")
    lens = f.split("-")[1]
    category = f.split("-")[2].rstrip("123")
    
    print(category)
# Out:
# heavy
# heavy
# heavy2_MetaWear_2019
# heavy2_MetaWear_2019
# heavy
# heavy
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium
# medium
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium
# medium
# medium
# medium
# medium
# medium
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# heavy1_MetaWear_2019
# heavy1_MetaWear_2019
# heavy2_MetaWear_2019
# heavy2_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy
# heavy
# heavy2_MetaWear_2019
# heavy2_MetaWear_2019
# heavy
# heavy
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium
# medium
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# sitting_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# standing_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# medium_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019
# heavy_MetaWear_2019

# %%
data_path = "../../data/raw/MetaMotion/"
f = files[1]

participant = f.split("-")[0].replace(data_path, "")
label = f.split("-")[1]
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

df = pd.read_csv(f)

df["participant"] = participant
df["label"] = label       
df["category"] = category

# --------------------------------------------------------------
# Read all files
# --------------------------------------------------------------

acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1
gyr_set = 1

for f in files:
    participant = f.split("-")[0].replace(data_path, "")
    lens = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

    
    print(category)
# Out:
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# sitting
# sitting
# sitting
# sitting
# standing
# standing
# standing
# standing
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# medium
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# sitting
# sitting
# sitting
# sitting
# standing
# standing
# standing
# standing
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# heavy
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# medium
# heavy
# heavy
# heavy
# heavy

# %%
print(label)
# Out:
# bench

# %%
data_path = "../../data/raw/MetaMotion/"
f = files[1]

participant = f.split("-")[0].replace(data_path, "")
label = f.split("-")[1]
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

df = pd.read_csv(f)

df["participant"] = participant
df["label"] = label       
df["category"] = category

# --------------------------------------------------------------
# Read all files
# --------------------------------------------------------------

acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1
gyr_set = 1

for f in files:
    participant = f.split("-")[0].replace(data_path, "")
    lens = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

    
    print(label)
# Out:
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench
# bench

# %%
data_path = "../../data/raw/MetaMotion/"
f = files[1]

participant = f.split("-")[0].replace(data_path, "")
label = f.split("-")[1]
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

df = pd.read_csv(f)

df["participant"] = participant
df["label"] = label       
df["category"] = category

# --------------------------------------------------------------
# Read all files
# --------------------------------------------------------------

acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1
gyr_set = 1

for f in files:
    participant = f.split("-")[0].replace(data_path, "")
    lens = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

    
    print(participant)
# Out:
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\A
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\B
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\C
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\D
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E
# ../../data/raw/MetaMotion\E

# %%
df = pd.read_csv(f)

# %%
df = pd.read_csv(f)
df["participant"] = participant
df["label"] = label
df["category"] = category

# %%
df["participant"] = participant

# %%
df["label"] = label

# %%
df["category"] = category

# %%
f
# Out:
# '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv'

# %%
f
# Out:
# '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv'

# %%
f
# Out:
# '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv'

# %%
f
# Out:
# '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv'

# %%
f
# Out:
# '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv'

# %%
data_path = "../../data/raw/MetaMotion/"
f = files[1]

participant = f.split("-")[0].replace(data_path, "")
label = f.split("-")[1]
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

df = pd.read_csv(f)

df["participant"] = participant
df["label"] = label       
df["category"] = category

# --------------------------------------------------------------
# Read all files
# --------------------------------------------------------------

acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1
gyr_set = 1

for f in files:
    participant = f.split("-")[0].replace(data_path, "")
    lens = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

    
    df = pd.read_csv(f)
    
    df["participant"] = participant
    df["label"] = label
    df["category"] = category

# %%
f
# Out:
# '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv'

# %%
f
# Out:
# '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv'

# %%
files
# Out:
# ['../../data/raw/MetaMotion\\A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.38.54.580_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.38.54.580_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.41.24.439_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.41.24.439_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy3-rpe7_MetaWear_2019-01-11T16.44.00.801_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy3-rpe7_MetaWear_2019-01-11T16.44.00.801_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium1-rpe7_MetaWear_2019-01-11T16.53.53.376_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium1-rpe7_MetaWear_2019-01-11T16.53.53.376_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium2-rpe7_MetaWear_2019-01-11T16.57.30.113_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium2-rpe7_MetaWear_2019-01-11T16.57.30.113_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium3-rpe7_MetaWear_2019-01-11T17.00.49.801_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium3-rpe7_MetaWear_2019-01-11T17.00.49.801_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.04.08.637_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.04.08.637_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium1-rpe7_MetaWear_2019-01-11T17.05.44.498_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium1-rpe7_MetaWear_2019-01-11T17.05.44.498_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium2-rpe8_MetaWear_2019-01-11T17.17.15.443_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium2-rpe8_MetaWear_2019-01-11T17.17.15.443_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium3-rpe7_MetaWear_2019-01-11T17.19.34.896_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium3-rpe7_MetaWear_2019-01-11T17.19.34.896_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy1-rpe8_MetaWear_2019-01-11T16.08.04.758_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy1-rpe8_MetaWear_2019-01-11T16.08.04.758_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy2-rpe8_MetaWear_2019-01-11T16.12.04.794_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy2-rpe8_MetaWear_2019-01-11T16.12.04.794_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.40.07.902_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.40.07.902_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.42.43.398_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.42.43.398_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy3-rpe8_MetaWear_2019-01-11T16.45.55.708_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy3-rpe8_MetaWear_2019-01-11T16.45.55.708_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium1-rpe8_MetaWear_2019-01-11T16.48.54.290_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium1-rpe8_MetaWear_2019-01-11T16.48.54.290_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium2-rpe8_MetaWear_2019-01-11T16.55.53.154_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium2-rpe8_MetaWear_2019-01-11T16.55.53.154_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium3-rpe9_MetaWear_2019-01-11T16.59.28.181_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium3-rpe9_MetaWear_2019-01-11T16.59.28.181_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-squat-medium1-rpe9_MetaWear_2019-01-11T17.09.32.694_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-squat-medium1-rpe9_MetaWear_2019-01-11T17.09.32.694_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy1_MetaWear_2019-01-14T14.29.37.418_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy1_MetaWear_2019-01-14T14.29.37.418_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy2_MetaWear_2019-01-14T14.32.11.392_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy2_MetaWear_2019-01-14T14.32.11.392_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy_MetaWear_2019-01-14T14.51.27.130_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy_MetaWear_2019-01-14T14.51.27.130_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.28.15.269_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.28.15.269_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.32.32.136_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.32.32.136_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.37.17.794_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.37.17.794_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.54.34.321_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.54.34.321_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.57.26.702_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.57.26.702_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.06.31.280_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.06.31.280_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.11.55.634_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.11.55.634_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.17.27.856_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.17.27.856_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-heavy_MetaWear_2019-01-18T18.03.51.096_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-heavy_MetaWear_2019-01-18T18.03.51.096_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.45.47.575_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.45.47.575_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.51.40.910_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.51.40.910_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv']

# %%
f = files[1]

# %%
1
# Out:
# 1

# %%
files
# Out:
# ['../../data/raw/MetaMotion\\A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.38.54.580_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.38.54.580_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.41.24.439_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.41.24.439_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy3-rpe7_MetaWear_2019-01-11T16.44.00.801_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy3-rpe7_MetaWear_2019-01-11T16.44.00.801_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium1-rpe7_MetaWear_2019-01-11T16.53.53.376_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium1-rpe7_MetaWear_2019-01-11T16.53.53.376_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium2-rpe7_MetaWear_2019-01-11T16.57.30.113_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium2-rpe7_MetaWear_2019-01-11T16.57.30.113_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium3-rpe7_MetaWear_2019-01-11T17.00.49.801_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-ohp-medium3-rpe7_MetaWear_2019-01-11T17.00.49.801_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.04.08.637_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.04.08.637_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium1-rpe7_MetaWear_2019-01-11T17.05.44.498_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium1-rpe7_MetaWear_2019-01-11T17.05.44.498_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium2-rpe8_MetaWear_2019-01-11T17.17.15.443_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium2-rpe8_MetaWear_2019-01-11T17.17.15.443_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium3-rpe7_MetaWear_2019-01-11T17.19.34.896_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\A-squat-medium3-rpe7_MetaWear_2019-01-11T17.19.34.896_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy1-rpe8_MetaWear_2019-01-11T16.08.04.758_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy1-rpe8_MetaWear_2019-01-11T16.08.04.758_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy2-rpe8_MetaWear_2019-01-11T16.12.04.794_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-bench-heavy2-rpe8_MetaWear_2019-01-11T16.12.04.794_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.40.07.902_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy1-rpe8_MetaWear_2019-01-11T16.40.07.902_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.42.43.398_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.42.43.398_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy3-rpe8_MetaWear_2019-01-11T16.45.55.708_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-heavy3-rpe8_MetaWear_2019-01-11T16.45.55.708_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium1-rpe8_MetaWear_2019-01-11T16.48.54.290_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium1-rpe8_MetaWear_2019-01-11T16.48.54.290_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium2-rpe8_MetaWear_2019-01-11T16.55.53.154_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium2-rpe8_MetaWear_2019-01-11T16.55.53.154_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium3-rpe9_MetaWear_2019-01-11T16.59.28.181_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-ohp-medium3-rpe9_MetaWear_2019-01-11T16.59.28.181_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-squat-medium1-rpe9_MetaWear_2019-01-11T17.09.32.694_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\B-squat-medium1-rpe9_MetaWear_2019-01-11T17.09.32.694_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy1_MetaWear_2019-01-14T14.29.37.418_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy1_MetaWear_2019-01-14T14.29.37.418_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy2_MetaWear_2019-01-14T14.32.11.392_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy2_MetaWear_2019-01-14T14.32.11.392_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy_MetaWear_2019-01-14T14.51.27.130_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-bench-heavy_MetaWear_2019-01-14T14.51.27.130_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.28.15.269_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.28.15.269_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.32.32.136_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.32.32.136_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.37.17.794_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-dead-medium_MetaWear_2019-01-15T20.37.17.794_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.54.34.321_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.54.34.321_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.57.26.702_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-ohp-heavy_MetaWear_2019-01-14T14.57.26.702_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-heavy_MetaWear_2019-01-14T15.08.50.111_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.06.31.280_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.06.31.280_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.11.55.634_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.11.55.634_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.17.27.856_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\C-squat-heavy_MetaWear_2019-01-15T20.17.27.856_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-heavy_MetaWear_2019-01-18T18.03.51.096_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-heavy_MetaWear_2019-01-18T18.03.51.096_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.45.47.575_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.45.47.575_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.51.40.910_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\D-squat-medium_MetaWear_2019-01-18T17.51.40.910_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy3-rpe8_MetaWear_2019-01-11T16.14.45.178_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.12.13.952_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-bench-medium_MetaWear_2019-01-18T18.24.19.109_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-heavy_MetaWear_2019-01-15T20.35.27.174_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium1-rpe6_MetaWear_2019-01-11T17.24.24.832_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-dead-medium_MetaWear_2019-01-15T20.30.34.601_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.53.06.282_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-ohp-heavy_MetaWear_2019-01-14T14.55.42.246_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.04.06.123_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.33.07.895_C42732BE255C_Gyroscope_25.000Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv',
#  '../../data/raw/MetaMotion\\E-row-medium_MetaWear_2019-01-18T18.34.52.516_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
#  '../../data/raw/MetaMotion\\E-squat-heavy_MetaWear_2019-01-15T20.14.03.633_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv']

# %%
if "Accelerometer" in f:
    acc_df = pd.concat([acc_df, df])

# %%
if "Accelerometer" in f:
# Out:
#   Cell In[74], line 1
#     if "Accelerometer" in f:
#                             ^
# SyntaxError: incomplete input

# %%
acc_df = pd.concat([acc_df, df])

# %%
if "Gyroscope" in f:
# Out:
#   Cell In[76], line 1
#     if "Gyroscope" in f:
#                         ^
# SyntaxError: incomplete input

# %%
gyr_df = pd.concat([gyr_df, df])

# %%
if "Gyroscope" in f:
    gyr_df = pd.concat([gyr_df, df])

# %%
if "Accelerometer" in f:
    acc_df = pd.concat([acc_df, df])

# %%
acc_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0    1547666043834  2019-01-16 20:14:03.834         0.00         -10.549
# 1    1547666043874  2019-01-16 20:14:03.874         0.04          -8.963
# 2    1547666043914  2019-01-16 20:14:03.914         0.08          -2.378
# 3    1547666043954  2019-01-16 20:14:03.954         0.12          -2.500
# 4    1547666043994  2019-01-16 20:14:03.994         0.16         -11.037
# ..             ...                      ...          ...             ...
# 487  1547666063314  2019-01-16 20:14:23.314        19.48          -1.707
# 488  1547666063354  2019-01-16 20:14:23.354        19.52           0.915
# 489  1547666063394  2019-01-16 20:14:23.394        19.56           5.854
# 490  1547666063434  2019-01-16 20:14:23.434        19.60           4.268
# 491  1547666063474  2019-01-16 20:14:23.474        19.64          -1.098
#
#      y-axis (deg/s)  z-axis (deg/s)                  participant  label  \
# 0             1.646          -1.280  ../../data/raw/MetaMotion\E  bench
# 1             1.524          -0.732  ../../data/raw/MetaMotion\E  bench
# 2            -1.280           0.305  ../../data/raw/MetaMotion\E  bench
# 3             0.732          -1.829  ../../data/raw/MetaMotion\E  bench
# 4             3.780          -2.561  ../../data/raw/MetaMotion\E  bench
# ..              ...             ...                          ...    ...
# 487          -0.671           1.585  ../../data/raw/MetaMotion\E  bench
# 488           0.305           2.988  ../../data/raw/MetaMotion\E  bench
# 489          -2.561           1.463  ../../data/raw/MetaMotion\E  bench
# 490           0.549          -0.305  ../../data/raw/MetaMotion\E  bench
# 491           1.768          -0.122  ../../data/raw/MetaMotion\E  bench
#
#     category
# 0      heavy
# 1      heavy
# 2      heavy
# 3      heavy
# 4      heavy
# ..       ...
# 487    heavy
# 488    heavy
# 489    heavy
# 490    heavy
# 491    heavy
#
# [492 rows x 9 columns]

# %%
gyr_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0    1547666043834  2019-01-16 20:14:03.834         0.00         -10.549
# 1    1547666043874  2019-01-16 20:14:03.874         0.04          -8.963
# 2    1547666043914  2019-01-16 20:14:03.914         0.08          -2.378
# 3    1547666043954  2019-01-16 20:14:03.954         0.12          -2.500
# 4    1547666043994  2019-01-16 20:14:03.994         0.16         -11.037
# ..             ...                      ...          ...             ...
# 487  1547666063314  2019-01-16 20:14:23.314        19.48          -1.707
# 488  1547666063354  2019-01-16 20:14:23.354        19.52           0.915
# 489  1547666063394  2019-01-16 20:14:23.394        19.56           5.854
# 490  1547666063434  2019-01-16 20:14:23.434        19.60           4.268
# 491  1547666063474  2019-01-16 20:14:23.474        19.64          -1.098
#
#      y-axis (deg/s)  z-axis (deg/s)                  participant  label  \
# 0             1.646          -1.280  ../../data/raw/MetaMotion\E  bench
# 1             1.524          -0.732  ../../data/raw/MetaMotion\E  bench
# 2            -1.280           0.305  ../../data/raw/MetaMotion\E  bench
# 3             0.732          -1.829  ../../data/raw/MetaMotion\E  bench
# 4             3.780          -2.561  ../../data/raw/MetaMotion\E  bench
# ..              ...             ...                          ...    ...
# 487          -0.671           1.585  ../../data/raw/MetaMotion\E  bench
# 488           0.305           2.988  ../../data/raw/MetaMotion\E  bench
# 489          -2.561           1.463  ../../data/raw/MetaMotion\E  bench
# 490           0.549          -0.305  ../../data/raw/MetaMotion\E  bench
# 491           1.768          -0.122  ../../data/raw/MetaMotion\E  bench
#
#     category
# 0      heavy
# 1      heavy
# 2      heavy
# 3      heavy
# 4      heavy
# ..       ...
# 487    heavy
# 488    heavy
# 489    heavy
# 490    heavy
# 491    heavy
#
# [984 rows x 9 columns]

# %%
single_file_acc = pd.read_csv("../../data/raw/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv")

# %%
single_file_acc = pd.read_csv("../../data/raw/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv")

single_file_gyro = pd.read_csv("../../data/raw/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv")
# --------------------------------------------------------------
# List all data in data/raw/MetaMotion
# --------------------------------------------------------------

files = glob("../../data/raw/MetaMotion/*.csv")
len(files)

# --------------------------------------------------------------
# Extract features from filename
# --------------------------------------------------------------

data_path = "../../data/raw/MetaMotion/"
f = files[1]

participant = f.split("-")[0].replace(data_path, "")
label = f.split("-")[1]
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

df = pd.read_csv(f)

df["participant"] = participant
df["label"] = label       
df["category"] = category

# --------------------------------------------------------------
# Read all files
# --------------------------------------------------------------

acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1
gyr_set = 1

for f in files:
    participant = f.split("-")[0].replace(data_path, "")
    lens = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

    
    df = pd.read_csv(f)
    df["participant"] = participant
    df["label"] = label
    df["category"] = category

if "Accelerometer" in f:
    acc_df = pd.concat([acc_df, df])
    
if "Gyroscope" in f:
    gyr_df = pd.concat([gyr_df, df])

# %%
acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1
gyr_set = 1

for f in files:
    
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

    
    df = pd.read_csv(f)
    df["participant"] = participant
    df["label"] = label
    df["category"] = category

if "Accelerometer" in f:
    acc_df = pd.concat([acc_df, df])
    
if "Gyroscope" in f:
    gyr_df = pd.concat([gyr_df, df])

# %%
acc_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
acc_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
if "Accelerometer" in f:
    acc_df = pd.concat([acc_df, df])

# %%
acc_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
acc_df = pd.DataFrame()

# %%
gyr_df = pd.DataFrame()

# %%
acc_set = 1

# %%
gyr_set = 1

# %%
participant = f.split("-")[0].replace(data_path, "")

# %%
label = f.split("-")[1]

# %%
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

# %%
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

# %%
df = pd.read_csv(f)

# %%
df["participant"] = participant

# %%
df["label"] = label

# %%
df["category"] = category

# %%
if "Accelerometer" in f:
    acc_df = pd.concat([acc_df, df])

# %%
if "Gyroscope" in f:
    gyr_df = pd.concat([gyr_df, df])

# %%
acc_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
acc_df = pd.concat([acc_df, df])

# %%
acc_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0    1547666043834  2019-01-16 20:14:03.834         0.00         -10.549
# 1    1547666043874  2019-01-16 20:14:03.874         0.04          -8.963
# 2    1547666043914  2019-01-16 20:14:03.914         0.08          -2.378
# 3    1547666043954  2019-01-16 20:14:03.954         0.12          -2.500
# 4    1547666043994  2019-01-16 20:14:03.994         0.16         -11.037
# ..             ...                      ...          ...             ...
# 487  1547666063314  2019-01-16 20:14:23.314        19.48          -1.707
# 488  1547666063354  2019-01-16 20:14:23.354        19.52           0.915
# 489  1547666063394  2019-01-16 20:14:23.394        19.56           5.854
# 490  1547666063434  2019-01-16 20:14:23.434        19.60           4.268
# 491  1547666063474  2019-01-16 20:14:23.474        19.64          -1.098
#
#      y-axis (deg/s)  z-axis (deg/s)                  participant  label  \
# 0             1.646          -1.280  ../../data/raw/MetaMotion\E  squat
# 1             1.524          -0.732  ../../data/raw/MetaMotion\E  squat
# 2            -1.280           0.305  ../../data/raw/MetaMotion\E  squat
# 3             0.732          -1.829  ../../data/raw/MetaMotion\E  squat
# 4             3.780          -2.561  ../../data/raw/MetaMotion\E  squat
# ..              ...             ...                          ...    ...
# 487          -0.671           1.585  ../../data/raw/MetaMotion\E  squat
# 488           0.305           2.988  ../../data/raw/MetaMotion\E  squat
# 489          -2.561           1.463  ../../data/raw/MetaMotion\E  squat
# 490           0.549          -0.305  ../../data/raw/MetaMotion\E  squat
# 491           1.768          -0.122  ../../data/raw/MetaMotion\E  squat
#
#     category
# 0      heavy
# 1      heavy
# 2      heavy
# 3      heavy
# 4      heavy
# ..       ...
# 487    heavy
# 488    heavy
# 489    heavy
# 490    heavy
# 491    heavy
#
# [492 rows x 9 columns]

# %%
if "Accelerometer" in f:
    acc_df = pd.concat([acc_df, df])

# %%
acc_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0    1547666043834  2019-01-16 20:14:03.834         0.00         -10.549
# 1    1547666043874  2019-01-16 20:14:03.874         0.04          -8.963
# 2    1547666043914  2019-01-16 20:14:03.914         0.08          -2.378
# 3    1547666043954  2019-01-16 20:14:03.954         0.12          -2.500
# 4    1547666043994  2019-01-16 20:14:03.994         0.16         -11.037
# ..             ...                      ...          ...             ...
# 487  1547666063314  2019-01-16 20:14:23.314        19.48          -1.707
# 488  1547666063354  2019-01-16 20:14:23.354        19.52           0.915
# 489  1547666063394  2019-01-16 20:14:23.394        19.56           5.854
# 490  1547666063434  2019-01-16 20:14:23.434        19.60           4.268
# 491  1547666063474  2019-01-16 20:14:23.474        19.64          -1.098
#
#      y-axis (deg/s)  z-axis (deg/s)                  participant  label  \
# 0             1.646          -1.280  ../../data/raw/MetaMotion\E  squat
# 1             1.524          -0.732  ../../data/raw/MetaMotion\E  squat
# 2            -1.280           0.305  ../../data/raw/MetaMotion\E  squat
# 3             0.732          -1.829  ../../data/raw/MetaMotion\E  squat
# 4             3.780          -2.561  ../../data/raw/MetaMotion\E  squat
# ..              ...             ...                          ...    ...
# 487          -0.671           1.585  ../../data/raw/MetaMotion\E  squat
# 488           0.305           2.988  ../../data/raw/MetaMotion\E  squat
# 489          -2.561           1.463  ../../data/raw/MetaMotion\E  squat
# 490           0.549          -0.305  ../../data/raw/MetaMotion\E  squat
# 491           1.768          -0.122  ../../data/raw/MetaMotion\E  squat
#
#     category
# 0      heavy
# 1      heavy
# 2      heavy
# 3      heavy
# 4      heavy
# ..       ...
# 487    heavy
# 488    heavy
# 489    heavy
# 490    heavy
# 491    heavy
#
# [492 rows x 9 columns]

# %%
if "Accelerometer" in f:
    acc_df = pd.concat([acc_df, df])
    
if "Gyroscope" in f:
    gyr_df = pd.concat([gyr_df, df])

# %%
acc_df = pd.concat([acc_df, df])

# %%
acc_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0    1547666043834  2019-01-16 20:14:03.834         0.00         -10.549
# 1    1547666043874  2019-01-16 20:14:03.874         0.04          -8.963
# 2    1547666043914  2019-01-16 20:14:03.914         0.08          -2.378
# 3    1547666043954  2019-01-16 20:14:03.954         0.12          -2.500
# 4    1547666043994  2019-01-16 20:14:03.994         0.16         -11.037
# ..             ...                      ...          ...             ...
# 487  1547666063314  2019-01-16 20:14:23.314        19.48          -1.707
# 488  1547666063354  2019-01-16 20:14:23.354        19.52           0.915
# 489  1547666063394  2019-01-16 20:14:23.394        19.56           5.854
# 490  1547666063434  2019-01-16 20:14:23.434        19.60           4.268
# 491  1547666063474  2019-01-16 20:14:23.474        19.64          -1.098
#
#      y-axis (deg/s)  z-axis (deg/s)                  participant  label  \
# 0             1.646          -1.280  ../../data/raw/MetaMotion\E  squat
# 1             1.524          -0.732  ../../data/raw/MetaMotion\E  squat
# 2            -1.280           0.305  ../../data/raw/MetaMotion\E  squat
# 3             0.732          -1.829  ../../data/raw/MetaMotion\E  squat
# 4             3.780          -2.561  ../../data/raw/MetaMotion\E  squat
# ..              ...             ...                          ...    ...
# 487          -0.671           1.585  ../../data/raw/MetaMotion\E  squat
# 488           0.305           2.988  ../../data/raw/MetaMotion\E  squat
# 489          -2.561           1.463  ../../data/raw/MetaMotion\E  squat
# 490           0.549          -0.305  ../../data/raw/MetaMotion\E  squat
# 491           1.768          -0.122  ../../data/raw/MetaMotion\E  squat
#
#     category
# 0      heavy
# 1      heavy
# 2      heavy
# 3      heavy
# 4      heavy
# ..       ...
# 487    heavy
# 488    heavy
# 489    heavy
# 490    heavy
# 491    heavy
#
# [984 rows x 9 columns]

# %%
acc_df = pd.DataFrame()

# %%
gyr_df = pd.DataFrame()

# %%
acc_set = 1

# %%
gyr_set = 1

# %%
for f in files:
# Out:
#   Cell In[115], line 1
#     for f in files:
#                    ^
# SyntaxError: incomplete input

# %%
for f in files:
    
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

    df = pd.read_csv(f)

    df["participant"] = participant
    df["label"] = label
    df["category"] = category

    if "Accelerometer" in f:
        acc_df = pd.concat([acc_df, df])

    if "Gyroscope" in f:
        gyr_df = pd.concat([gyr_df, df])

# %%
gyr_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0    1547219408351  2019-01-11T16:10:08.351         0.00           0.122
# 1    1547219408391  2019-01-11T16:10:08.391         0.04           2.195
# 2    1547219408431  2019-01-11T16:10:08.431         0.08           2.622
# 3    1547219408471  2019-01-11T16:10:08.471         0.12           1.951
# 4    1547219408511  2019-01-11T16:10:08.511         0.16           1.524
# ..             ...                      ...          ...             ...
# 487  1547666063314  2019-01-16 20:14:23.314        19.48          -1.707
# 488  1547666063354  2019-01-16 20:14:23.354        19.52           0.915
# 489  1547666063394  2019-01-16 20:14:23.394        19.56           5.854
# 490  1547666063434  2019-01-16 20:14:23.434        19.60           4.268
# 491  1547666063474  2019-01-16 20:14:23.474        19.64          -1.098
#
#      y-axis (deg/s)  z-axis (deg/s)                  participant  label  \
# 0            -5.488          -3.841  ../../data/raw/MetaMotion\A  bench
# 1            -9.695          -0.610  ../../data/raw/MetaMotion\A  bench
# 2            -8.110          -4.024  ../../data/raw/MetaMotion\A  bench
# 3            -4.695          -4.634  ../../data/raw/MetaMotion\A  bench
# 4            -2.561          -2.500  ../../data/raw/MetaMotion\A  bench
# ..              ...             ...                          ...    ...
# 487          -0.671           1.585  ../../data/raw/MetaMotion\E  squat
# 488           0.305           2.988  ../../data/raw/MetaMotion\E  squat
# 489          -2.561           1.463  ../../data/raw/MetaMotion\E  squat
# 490           0.549          -0.305  ../../data/raw/MetaMotion\E  squat
# 491           1.768          -0.122  ../../data/raw/MetaMotion\E  squat
#
#     category
# 0      heavy
# 1      heavy
# 2      heavy
# 3      heavy
# 4      heavy
# ..       ...
# 487    heavy
# 488    heavy
# 489    heavy
# 490    heavy
# 491    heavy
#
# [47218 rows x 9 columns]

# %%
acc_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547219408431  2019-01-11T16:10:08.431         0.00       0.010
# 1    1547219408511  2019-01-11T16:10:08.511         0.08       0.000
# 2    1547219408591  2019-01-11T16:10:08.591         0.16       0.001
# 3    1547219408671  2019-01-11T16:10:08.671         0.24      -0.012
# 4    1547219408751  2019-01-11T16:10:08.751         0.32      -0.013
# ..             ...                      ...          ...         ...
# 237  1547666063089  2019-01-16 20:14:23.089        18.96       0.012
# 238  1547666063169  2019-01-16 20:14:23.169        19.04       0.009
# 239  1547666063249  2019-01-16 20:14:23.249        19.12       0.015
# 240  1547666063329  2019-01-16 20:14:23.329        19.20       0.006
# 241  1547666063409  2019-01-16 20:14:23.409        19.28       0.015
#
#      y-axis (g)  z-axis (g)                  participant  label category
# 0         0.964      -0.087  ../../data/raw/MetaMotion\A  bench    heavy
# 1         0.961      -0.069  ../../data/raw/MetaMotion\A  bench    heavy
# 2         0.974      -0.087  ../../data/raw/MetaMotion\A  bench    heavy
# 3         0.971      -0.084  ../../data/raw/MetaMotion\A  bench    heavy
# 4         0.954      -0.094  ../../data/raw/MetaMotion\A  bench    heavy
# ..          ...         ...                          ...    ...      ...
# 237       0.596       0.815  ../../data/raw/MetaMotion\E  squat    heavy
# 238       0.528       0.821  ../../data/raw/MetaMotion\E  squat    heavy
# 239       0.554       0.746  ../../data/raw/MetaMotion\E  squat    heavy
# 240       0.574       0.824  ../../data/raw/MetaMotion\E  squat    heavy
# 241       0.588       0.826  ../../data/raw/MetaMotion\E  squat    heavy
#
# [23578 rows x 9 columns]

# %%
acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1 
gyr_set = 1

# %%
acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1 
gyr_set = 1

# %%
for f in files:
    
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

    df = pd.read_csv(f)

    df["participant"] = participant
    df["label"] = label
    df["category"] = category

    if "Accelerometer" in f:
        df["set"] = acc_set
        acc_set += 1
        acc_df = pd.concat([acc_df, df])

    if "Gyroscope" in f:
        df["set"] = gyr_set
        gyr_set += 1
        gyr_df = pd.concat([gyr_df, df])

# %%
acc_df = pd.concat([acc_df, df])

# %%
acc_df
# Out:
#         epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0    1547219408431  2019-01-11T16:10:08.431         0.00       0.010
# 1    1547219408511  2019-01-11T16:10:08.511         0.08       0.000
# 2    1547219408591  2019-01-11T16:10:08.591         0.16       0.001
# 3    1547219408671  2019-01-11T16:10:08.671         0.24      -0.012
# 4    1547219408751  2019-01-11T16:10:08.751         0.32      -0.013
# ..             ...                      ...          ...         ...
# 487  1547666063314  2019-01-16 20:14:23.314        19.48         NaN
# 488  1547666063354  2019-01-16 20:14:23.354        19.52         NaN
# 489  1547666063394  2019-01-16 20:14:23.394        19.56         NaN
# 490  1547666063434  2019-01-16 20:14:23.434        19.60         NaN
# 491  1547666063474  2019-01-16 20:14:23.474        19.64         NaN
#
#      y-axis (g)  z-axis (g)                  participant  label category  set  \
# 0         0.964      -0.087  ../../data/raw/MetaMotion\A  bench    heavy    1
# 1         0.961      -0.069  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2         0.974      -0.087  ../../data/raw/MetaMotion\A  bench    heavy    1
# 3         0.971      -0.084  ../../data/raw/MetaMotion\A  bench    heavy    1
# 4         0.954      -0.094  ../../data/raw/MetaMotion\A  bench    heavy    1
# ..          ...         ...                          ...    ...      ...  ...
# 487         NaN         NaN  ../../data/raw/MetaMotion\E  squat    heavy   93
# 488         NaN         NaN  ../../data/raw/MetaMotion\E  squat    heavy   93
# 489         NaN         NaN  ../../data/raw/MetaMotion\E  squat    heavy   93
# 490         NaN         NaN  ../../data/raw/MetaMotion\E  squat    heavy   93
# 491         NaN         NaN  ../../data/raw/MetaMotion\E  squat    heavy   93
#
#      x-axis (deg/s)  y-axis (deg/s)  z-axis (deg/s)
# 0               NaN             NaN             NaN
# 1               NaN             NaN             NaN
# 2               NaN             NaN             NaN
# 3               NaN             NaN             NaN
# 4               NaN             NaN             NaN
# ..              ...             ...             ...
# 487          -1.707          -0.671           1.585
# 488           0.915           0.305           2.988
# 489           5.854          -2.561           1.463
# 490           4.268           0.549          -0.305
# 491          -1.098           1.768          -0.122
#
# [24070 rows x 13 columns]

# %%
acc_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 24070 entries, 0 to 491
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   epoch (ms)      24070 non-null  int64
#  1   time (01:00)    24070 non-null  str
#  2   elapsed (s)     24070 non-null  float64
#  3   x-axis (g)      23578 non-null  float64
#  4   y-axis (g)      23578 non-null  float64
#  5   z-axis (g)      23578 non-null  float64
#  6   participant     24070 non-null  str
#  7   label           24070 non-null  str
#  8   category        24070 non-null  str
#  9   set             24070 non-null  int64
#  10  x-axis (deg/s)  492 non-null    float64
#  11  y-axis (deg/s)  492 non-null    float64
#  12  z-axis (deg/s)  492 non-null    float64
# dtypes: float64(7), int64(2), str(4)
# memory usage: 2.6 MB

# %%
pd.to_datetime(df["epoch"], unit="ms")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'epoch'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 pd.to_datetime(df["epoch"], unit="ms")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'epoch'

# %%
acc_df.info()

pd.to_datetime(df["epoch"], unit="ms")
# Out:
# <class 'pandas.DataFrame'>
# Index: 24070 entries, 0 to 491
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   epoch (ms)      24070 non-null  int64
#  1   time (01:00)    24070 non-null  str
#  2   elapsed (s)     24070 non-null  float64
#  3   x-axis (g)      23578 non-null  float64
#  4   y-axis (g)      23578 non-null  float64
#  5   z-axis (g)      23578 non-null  float64
#  6   participant     24070 non-null  str
#  7   label           24070 non-null  str
#  8   category        24070 non-null  str
#  9   set             24070 non-null  int64
#  10  x-axis (deg/s)  492 non-null    float64
#  11  y-axis (deg/s)  492 non-null    float64
#  12  z-axis (deg/s)  492 non-null    float64
# dtypes: float64(7), int64(2), str(4)
# memory usage: 2.6 MB
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'epoch'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[126], line 3
#       1 acc_df.info()
# ----> 3 pd.to_datetime(df["epoch"], unit="ms")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'epoch'

# %%
pd.to_datetime(acc_df["epoch"], unit="ms")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'epoch'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 pd.to_datetime(acc_df["epoch"], unit="ms")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'epoch'

# %%
pd.to_datetime(df["epoch (ms)"], unit="ms")
# Out:
# 0     2019-01-16 19:14:03.834
# 1     2019-01-16 19:14:03.874
# 2     2019-01-16 19:14:03.914
# 3     2019-01-16 19:14:03.954
# 4     2019-01-16 19:14:03.994
#                 ...
# 487   2019-01-16 19:14:23.314
# 488   2019-01-16 19:14:23.354
# 489   2019-01-16 19:14:23.394
# 490   2019-01-16 19:14:23.434
# 491   2019-01-16 19:14:23.474
# Name: epoch (ms), Length: 492, dtype: datetime64[ms]

# %%
df["time (01:00:00)"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time (01:00:00)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 df["time (01:00:00)"]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'time (01:00:00)'

# %%
df["time (01:00)"]
# Out:
# 0      2019-01-16 20:14:03.834
# 1      2019-01-16 20:14:03.874
# 2      2019-01-16 20:14:03.914
# 3      2019-01-16 20:14:03.954
# 4      2019-01-16 20:14:03.994
#                 ...
# 487    2019-01-16 20:14:23.314
# 488    2019-01-16 20:14:23.354
# 489    2019-01-16 20:14:23.394
# 490    2019-01-16 20:14:23.434
# 491    2019-01-16 20:14:23.474
# Name: time (01:00), Length: 492, dtype: str

# %%
acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms")

# %%
acc_df
# Out:
#                             epoch (ms)             time (01:00)  elapsed (s)  \
# epoch (ms)
# 2019-01-11 15:10:08.431  1547219408431  2019-01-11T16:10:08.431         0.00
# 2019-01-11 15:10:08.511  1547219408511  2019-01-11T16:10:08.511         0.08
# 2019-01-11 15:10:08.591  1547219408591  2019-01-11T16:10:08.591         0.16
# 2019-01-11 15:10:08.671  1547219408671  2019-01-11T16:10:08.671         0.24
# 2019-01-11 15:10:08.751  1547219408751  2019-01-11T16:10:08.751         0.32
# ...                                ...                      ...          ...
# 2019-01-16 19:14:23.314  1547666063314  2019-01-16 20:14:23.314        19.48
# 2019-01-16 19:14:23.354  1547666063354  2019-01-16 20:14:23.354        19.52
# 2019-01-16 19:14:23.394  1547666063394  2019-01-16 20:14:23.394        19.56
# 2019-01-16 19:14:23.434  1547666063434  2019-01-16 20:14:23.434        19.60
# 2019-01-16 19:14:23.474  1547666063474  2019-01-16 20:14:23.474        19.64
#
#                          x-axis (g)  y-axis (g)  z-axis (g)  \
# epoch (ms)
# 2019-01-11 15:10:08.431       0.010       0.964      -0.087
# 2019-01-11 15:10:08.511       0.000       0.961      -0.069
# 2019-01-11 15:10:08.591       0.001       0.974      -0.087
# 2019-01-11 15:10:08.671      -0.012       0.971      -0.084
# 2019-01-11 15:10:08.751      -0.013       0.954      -0.094
# ...                             ...         ...         ...
# 2019-01-16 19:14:23.314         NaN         NaN         NaN
# 2019-01-16 19:14:23.354         NaN         NaN         NaN
# 2019-01-16 19:14:23.394         NaN         NaN         NaN
# 2019-01-16 19:14:23.434         NaN         NaN         NaN
# 2019-01-16 19:14:23.474         NaN         NaN         NaN
#
#                                          participant  label category  set  \
# epoch (ms)
# 2019-01-11 15:10:08.431  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.511  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.591  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.671  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.751  ../../data/raw/MetaMotion\A  bench    heavy    1
# ...                                              ...    ...      ...  ...
# 2019-01-16 19:14:23.314  ../../data/raw/MetaMotion\E  squat    heavy   93
# 2019-01-16 19:14:23.354  ../../data/raw/MetaMotion\E  squat    heavy   93
# 2019-01-16 19:14:23.394  ../../data/raw/MetaMotion\E  squat    heavy   93
# 2019-01-16 19:14:23.434  ../../data/raw/MetaMotion\E  squat    heavy   93
# 2019-01-16 19:14:23.474  ../../data/raw/MetaMotion\E  squat    heavy   93
#
#                          x-axis (deg/s)  y-axis (deg/s)  z-axis (deg/s)
# epoch (ms)
# 2019-01-11 15:10:08.431             NaN             NaN             NaN
# 2019-01-11 15:10:08.511             NaN             NaN             NaN
# 2019-01-11 15:10:08.591             NaN             NaN             NaN
# 2019-01-11 15:10:08.671             NaN             NaN             NaN
# 2019-01-11 15:10:08.751             NaN             NaN             NaN
# ...                                 ...             ...             ...
# 2019-01-16 19:14:23.314          -1.707          -0.671           1.585
# 2019-01-16 19:14:23.354           0.915           0.305           2.988
# 2019-01-16 19:14:23.394           5.854          -2.561           1.463
# 2019-01-16 19:14:23.434           4.268           0.549          -0.305
# 2019-01-16 19:14:23.474          -1.098           1.768          -0.122
#
# [24070 rows x 13 columns]

# %%
gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")

# %%
del acc_df["epoch (ms)"]
del acc_df["time (01:00)"]
del acc_df["elapsed (s) "]

del gyr_df["epoch (ms)"]
del gyr_df["time (01:00)"]      
del gyr_df["elapsed (s) "]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'elapsed (s) '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 3
#       1 del acc_df["epoch (ms)"]
#       2 del acc_df["time (01:00)"]
# ----> 3 del acc_df["elapsed (s) "]
#       5 del gyr_df["epoch (ms)"]
#       6 del gyr_df["time (01:00)"]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4350, in NDFrame.__delitem__(self, key)
#    4345             deleted = True
#    4346 if not deleted:
#    4347     # If the above loop ran and didn't delete anything because
#    4348     # there was no match, this call should raise the appropriate
#    4349     # exception:
# -> 4350     loc = self.axes[-1].get_loc(key)
#    4351     self._mgr = self._mgr.idelete(loc)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'elapsed (s) '

# %%
del acc_df["epoch (ms)"]
del acc_df["time (01:00)"]
del acc_df["elapsed (s)"]

del gyr_df["epoch (ms)"]
del gyr_df["time (01:00)"]      
del gyr_df["elapsed (s)"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'epoch (ms)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 del acc_df["epoch (ms)"]
#       2 del acc_df["time (01:00)"]
#       3 del acc_df["elapsed (s)"]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4350, in NDFrame.__delitem__(self, key)
#    4345             deleted = True
#    4346 if not deleted:
#    4347     # If the above loop ran and didn't delete anything because
#    4348     # there was no match, this call should raise the appropriate
#    4349     # exception:
# -> 4350     loc = self.axes[-1].get_loc(key)
#    4351     self._mgr = self._mgr.idelete(loc)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'epoch (ms)'

# %%
participant = f.split("-")[0].replace(data_path, "").rstrip("data_path")

# %%
data_path = "../../data/raw/MetaMotion/"
f = files[1]

participant = f.split("-")[0].replace(data_path, "").rstrip("data_path")
label = f.split("-")[1]
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

df = pd.read_csv(f)

df["participant"] = participant
df["label"] = label       
df["category"] = category

# --------------------------------------------------------------
# Read all files
# --------------------------------------------------------------

acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1 
gyr_set = 1


for f in files:
    
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

    df = pd.read_csv(f)

    df["participant"] = participant
    df["label"] = label
    df["category"] = category

    if "Accelerometer" in f:
        df["set"] = acc_set
        acc_set += 1
        acc_df = pd.concat([acc_df, df])

    if "Gyroscope" in f:
        df["set"] = gyr_set
        gyr_set += 1
        gyr_df = pd.concat([gyr_df, df])
        
# --------------------------------------------------------------
# Working with datetimes
# --------------------------------------------------------------
acc_df.info()

pd.to_datetime(df["epoch (ms)"], unit="ms") 
acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms") 
gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")

del acc_df["epoch (ms)"]
del acc_df["time (01:00)"]
del acc_df["elapsed (s)"]

del gyr_df["epoch (ms)"]
del gyr_df["time (01:00)"]      
del gyr_df["elapsed (s)"]
# Out:
# <class 'pandas.DataFrame'>
# Index: 23578 entries, 0 to 241
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   epoch (ms)    23578 non-null  int64
#  1   time (01:00)  23578 non-null  str
#  2   elapsed (s)   23578 non-null  float64
#  3   x-axis (g)    23578 non-null  float64
#  4   y-axis (g)    23578 non-null  float64
#  5   z-axis (g)    23578 non-null  float64
#  6   participant   23578 non-null  str
#  7   label         23578 non-null  str
#  8   category      23578 non-null  str
#  9   set           23578 non-null  int64
# dtypes: float64(4), int64(2), str(4)
# memory usage: 2.0 MB

# %%
acc_df
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g)  \
# epoch (ms)
# 2019-01-11 15:10:08.431       0.010       0.964      -0.087
# 2019-01-11 15:10:08.511       0.000       0.961      -0.069
# 2019-01-11 15:10:08.591       0.001       0.974      -0.087
# 2019-01-11 15:10:08.671      -0.012       0.971      -0.084
# 2019-01-11 15:10:08.751      -0.013       0.954      -0.094
# ...                             ...         ...         ...
# 2019-01-16 19:14:23.089       0.012       0.596       0.815
# 2019-01-16 19:14:23.169       0.009       0.528       0.821
# 2019-01-16 19:14:23.249       0.015       0.554       0.746
# 2019-01-16 19:14:23.329       0.006       0.574       0.824
# 2019-01-16 19:14:23.409       0.015       0.588       0.826
#
#                                          participant  label category  set
# epoch (ms)
# 2019-01-11 15:10:08.431  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.511  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.591  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.671  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.751  ../../data/raw/MetaMotion\A  bench    heavy    1
# ...                                              ...    ...      ...  ...
# 2019-01-16 19:14:23.089  ../../data/raw/MetaMotion\E  squat    heavy   94
# 2019-01-16 19:14:23.169  ../../data/raw/MetaMotion\E  squat    heavy   94
# 2019-01-16 19:14:23.249  ../../data/raw/MetaMotion\E  squat    heavy   94
# 2019-01-16 19:14:23.329  ../../data/raw/MetaMotion\E  squat    heavy   94
# 2019-01-16 19:14:23.409  ../../data/raw/MetaMotion\E  squat    heavy   94
#
# [23578 rows x 7 columns]

# %%
gyr_df
# Out:
#                          x-axis (deg/s)  y-axis (deg/s)  z-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:10:08.351           0.122          -5.488          -3.841
# 2019-01-11 15:10:08.391           2.195          -9.695          -0.610
# 2019-01-11 15:10:08.431           2.622          -8.110          -4.024
# 2019-01-11 15:10:08.471           1.951          -4.695          -4.634
# 2019-01-11 15:10:08.511           1.524          -2.561          -2.500
# ...                                 ...             ...             ...
# 2019-01-16 19:14:23.314          -1.707          -0.671           1.585
# 2019-01-16 19:14:23.354           0.915           0.305           2.988
# 2019-01-16 19:14:23.394           5.854          -2.561           1.463
# 2019-01-16 19:14:23.434           4.268           0.549          -0.305
# 2019-01-16 19:14:23.474          -1.098           1.768          -0.122
#
#                                          participant  label category  set
# epoch (ms)
# 2019-01-11 15:10:08.351  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.391  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.431  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.471  ../../data/raw/MetaMotion\A  bench    heavy    1
# 2019-01-11 15:10:08.511  ../../data/raw/MetaMotion\A  bench    heavy    1
# ...                                              ...    ...      ...  ...
# 2019-01-16 19:14:23.314  ../../data/raw/MetaMotion\E  squat    heavy   93
# 2019-01-16 19:14:23.354  ../../data/raw/MetaMotion\E  squat    heavy   93
# 2019-01-16 19:14:23.394  ../../data/raw/MetaMotion\E  squat    heavy   93
# 2019-01-16 19:14:23.434  ../../data/raw/MetaMotion\E  squat    heavy   93
# 2019-01-16 19:14:23.474  ../../data/raw/MetaMotion\E  squat    heavy   93
#
# [47218 rows x 7 columns]

# %%
data_path = "../../data/raw/MetaMotion\"
# Out:
#   Cell In[140], line 1
#     data_path = "../../data/raw/MetaMotion\"
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
data_path = "../../data/raw/MetaMotion\\"

# %%
data_path = "../../data/raw/MetaMotion\\"
f = files[1]

participant = f.split("-")[0].replace(data_path, "")
label = f.split("-")[1]
category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

df = pd.read_csv(f)

df["participant"] = participant
df["label"] = label       
df["category"] = category

# --------------------------------------------------------------
# Read all files
# --------------------------------------------------------------

acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1 
gyr_set = 1


for f in files:
    
    participant = f.split("-")[0].replace(data_path, "")
    label = f.split("-")[1]
    category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

    df = pd.read_csv(f)

    df["participant"] = participant
    df["label"] = label
    df["category"] = category

    if "Accelerometer" in f:
        df["set"] = acc_set
        acc_set += 1
        acc_df = pd.concat([acc_df, df])

    if "Gyroscope" in f:
        df["set"] = gyr_set
        gyr_set += 1
        gyr_df = pd.concat([gyr_df, df])
        
# --------------------------------------------------------------
# Working with datetimes
# --------------------------------------------------------------
acc_df.info()

pd.to_datetime(df["epoch (ms)"], unit="ms") 
acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms") 
gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")

del acc_df["epoch (ms)"]
del acc_df["time (01:00)"]
del acc_df["elapsed (s)"]

del gyr_df["epoch (ms)"]
del gyr_df["time (01:00)"]      
del gyr_df["elapsed (s)"]
# Out:
# <class 'pandas.DataFrame'>
# Index: 23578 entries, 0 to 241
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   epoch (ms)    23578 non-null  int64
#  1   time (01:00)  23578 non-null  str
#  2   elapsed (s)   23578 non-null  float64
#  3   x-axis (g)    23578 non-null  float64
#  4   y-axis (g)    23578 non-null  float64
#  5   z-axis (g)    23578 non-null  float64
#  6   participant   23578 non-null  str
#  7   label         23578 non-null  str
#  8   category      23578 non-null  str
#  9   set           23578 non-null  int64
# dtypes: float64(4), int64(2), str(4)
# memory usage: 2.0 MB

# %%
acc_df
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g) participant  \
# epoch (ms)
# 2019-01-11 15:10:08.431       0.010       0.964      -0.087           A
# 2019-01-11 15:10:08.511       0.000       0.961      -0.069           A
# 2019-01-11 15:10:08.591       0.001       0.974      -0.087           A
# 2019-01-11 15:10:08.671      -0.012       0.971      -0.084           A
# 2019-01-11 15:10:08.751      -0.013       0.954      -0.094           A
# ...                             ...         ...         ...         ...
# 2019-01-16 19:14:23.089       0.012       0.596       0.815           E
# 2019-01-16 19:14:23.169       0.009       0.528       0.821           E
# 2019-01-16 19:14:23.249       0.015       0.554       0.746           E
# 2019-01-16 19:14:23.329       0.006       0.574       0.824           E
# 2019-01-16 19:14:23.409       0.015       0.588       0.826           E
#
#                          label category  set
# epoch (ms)
# 2019-01-11 15:10:08.431  bench    heavy    1
# 2019-01-11 15:10:08.511  bench    heavy    1
# 2019-01-11 15:10:08.591  bench    heavy    1
# 2019-01-11 15:10:08.671  bench    heavy    1
# 2019-01-11 15:10:08.751  bench    heavy    1
# ...                        ...      ...  ...
# 2019-01-16 19:14:23.089  squat    heavy   94
# 2019-01-16 19:14:23.169  squat    heavy   94
# 2019-01-16 19:14:23.249  squat    heavy   94
# 2019-01-16 19:14:23.329  squat    heavy   94
# 2019-01-16 19:14:23.409  squat    heavy   94
#
# [23578 rows x 7 columns]

# %%
gyr_df
# Out:
#                          x-axis (deg/s)  y-axis (deg/s)  z-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:10:08.351           0.122          -5.488          -3.841
# 2019-01-11 15:10:08.391           2.195          -9.695          -0.610
# 2019-01-11 15:10:08.431           2.622          -8.110          -4.024
# 2019-01-11 15:10:08.471           1.951          -4.695          -4.634
# 2019-01-11 15:10:08.511           1.524          -2.561          -2.500
# ...                                 ...             ...             ...
# 2019-01-16 19:14:23.314          -1.707          -0.671           1.585
# 2019-01-16 19:14:23.354           0.915           0.305           2.988
# 2019-01-16 19:14:23.394           5.854          -2.561           1.463
# 2019-01-16 19:14:23.434           4.268           0.549          -0.305
# 2019-01-16 19:14:23.474          -1.098           1.768          -0.122
#
#                         participant  label category  set
# epoch (ms)
# 2019-01-11 15:10:08.351           A  bench    heavy    1
# 2019-01-11 15:10:08.391           A  bench    heavy    1
# 2019-01-11 15:10:08.431           A  bench    heavy    1
# 2019-01-11 15:10:08.471           A  bench    heavy    1
# 2019-01-11 15:10:08.511           A  bench    heavy    1
# ...                             ...    ...      ...  ...
# 2019-01-16 19:14:23.314           E  squat    heavy   93
# 2019-01-16 19:14:23.354           E  squat    heavy   93
# 2019-01-16 19:14:23.394           E  squat    heavy   93
# 2019-01-16 19:14:23.434           E  squat    heavy   93
# 2019-01-16 19:14:23.474           E  squat    heavy   93
#
# [47218 rows x 7 columns]

# %%
acc_df.info()

pd.to_datetime(df["epoch (ms)"], unit="ms") 
acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms") 
gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 23578 entries, 2019-01-11 15:10:08.431000 to 2019-01-16 19:14:23.409000
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   x-axis (g)   23578 non-null  float64
#  1   y-axis (g)   23578 non-null  float64
#  2   z-axis (g)   23578 non-null  float64
#  3   participant  23578 non-null  str
#  4   label        23578 non-null  str
#  5   category     23578 non-null  str
#  6   set          23578 non-null  int64
# dtypes: float64(3), int64(1), str(3)
# memory usage: 1.4 MB
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'epoch (ms)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[145], line 4
#       1 acc_df.info()
#       3 pd.to_datetime(df["epoch (ms)"], unit="ms")
# ----> 4 acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms")
#       5 gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'epoch (ms)'

# %%
acc_df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 23578 entries, 2019-01-11 15:10:08.431000 to 2019-01-16 19:14:23.409000
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   x-axis (g)   23578 non-null  float64
#  1   y-axis (g)   23578 non-null  float64
#  2   z-axis (g)   23578 non-null  float64
#  3   participant  23578 non-null  str
#  4   label        23578 non-null  str
#  5   category     23578 non-null  str
#  6   set          23578 non-null  int64
# dtypes: float64(3), int64(1), str(3)
# memory usage: 1.4 MB

# %%
pd.to_datetime(df["epoch (ms)"], unit="ms")
# Out:
# 0     2019-01-16 19:14:03.834
# 1     2019-01-16 19:14:03.874
# 2     2019-01-16 19:14:03.914
# 3     2019-01-16 19:14:03.954
# 4     2019-01-16 19:14:03.994
#                 ...
# 487   2019-01-16 19:14:23.314
# 488   2019-01-16 19:14:23.354
# 489   2019-01-16 19:14:23.394
# 490   2019-01-16 19:14:23.434
# 491   2019-01-16 19:14:23.474
# Name: epoch (ms), Length: 492, dtype: datetime64[ms]

# %%
acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'epoch (ms)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'epoch (ms)'

# %%
acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'epoch (ms)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'epoch (ms)'

# %%
gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'epoch (ms)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'epoch (ms)'

# %%
pd.to_datetime(df["epoch (ms)"], unit="ms")
# Out:
# 0     2019-01-16 19:14:03.834
# 1     2019-01-16 19:14:03.874
# 2     2019-01-16 19:14:03.914
# 3     2019-01-16 19:14:03.954
# 4     2019-01-16 19:14:03.994
#                 ...
# 487   2019-01-16 19:14:23.314
# 488   2019-01-16 19:14:23.354
# 489   2019-01-16 19:14:23.394
# 490   2019-01-16 19:14:23.434
# 491   2019-01-16 19:14:23.474
# Name: epoch (ms), Length: 492, dtype: datetime64[ms]

# %%
acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'epoch (ms)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'epoch (ms)'

# %%
acc_df
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g) participant  \
# epoch (ms)
# 2019-01-11 15:10:08.431       0.010       0.964      -0.087           A
# 2019-01-11 15:10:08.511       0.000       0.961      -0.069           A
# 2019-01-11 15:10:08.591       0.001       0.974      -0.087           A
# 2019-01-11 15:10:08.671      -0.012       0.971      -0.084           A
# 2019-01-11 15:10:08.751      -0.013       0.954      -0.094           A
# ...                             ...         ...         ...         ...
# 2019-01-16 19:14:23.089       0.012       0.596       0.815           E
# 2019-01-16 19:14:23.169       0.009       0.528       0.821           E
# 2019-01-16 19:14:23.249       0.015       0.554       0.746           E
# 2019-01-16 19:14:23.329       0.006       0.574       0.824           E
# 2019-01-16 19:14:23.409       0.015       0.588       0.826           E
#
#                          label category  set
# epoch (ms)
# 2019-01-11 15:10:08.431  bench    heavy    1
# 2019-01-11 15:10:08.511  bench    heavy    1
# 2019-01-11 15:10:08.591  bench    heavy    1
# 2019-01-11 15:10:08.671  bench    heavy    1
# 2019-01-11 15:10:08.751  bench    heavy    1
# ...                        ...      ...  ...
# 2019-01-16 19:14:23.089  squat    heavy   94
# 2019-01-16 19:14:23.169  squat    heavy   94
# 2019-01-16 19:14:23.249  squat    heavy   94
# 2019-01-16 19:14:23.329  squat    heavy   94
# 2019-01-16 19:14:23.409  squat    heavy   94
#
# [23578 rows x 7 columns]

# %%
gyr_df
# Out:
#                          x-axis (deg/s)  y-axis (deg/s)  z-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:10:08.351           0.122          -5.488          -3.841
# 2019-01-11 15:10:08.391           2.195          -9.695          -0.610
# 2019-01-11 15:10:08.431           2.622          -8.110          -4.024
# 2019-01-11 15:10:08.471           1.951          -4.695          -4.634
# 2019-01-11 15:10:08.511           1.524          -2.561          -2.500
# ...                                 ...             ...             ...
# 2019-01-16 19:14:23.314          -1.707          -0.671           1.585
# 2019-01-16 19:14:23.354           0.915           0.305           2.988
# 2019-01-16 19:14:23.394           5.854          -2.561           1.463
# 2019-01-16 19:14:23.434           4.268           0.549          -0.305
# 2019-01-16 19:14:23.474          -1.098           1.768          -0.122
#
#                         participant  label category  set
# epoch (ms)
# 2019-01-11 15:10:08.351           A  bench    heavy    1
# 2019-01-11 15:10:08.391           A  bench    heavy    1
# 2019-01-11 15:10:08.431           A  bench    heavy    1
# 2019-01-11 15:10:08.471           A  bench    heavy    1
# 2019-01-11 15:10:08.511           A  bench    heavy    1
# ...                             ...    ...      ...  ...
# 2019-01-16 19:14:23.314           E  squat    heavy   93
# 2019-01-16 19:14:23.354           E  squat    heavy   93
# 2019-01-16 19:14:23.394           E  squat    heavy   93
# 2019-01-16 19:14:23.434           E  squat    heavy   93
# 2019-01-16 19:14:23.474           E  squat    heavy   93
#
# [47218 rows x 7 columns]

# %%
files = glob("../../data/raw/MetaMotion/*.csv")

def read_files(files):
    acc_df = pd.DataFrame()
    gyr_df = pd.DataFrame()

    acc_set = 1 
    gyr_set = 1

    for f in files:
    
        participant = f.split("-")[0].replace(data_path, "")
        label = f.split("-")[1]
        category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

        df = pd.read_csv(f)

        df["participant"] = participant
        df["label"] = label
        df["category"] = category

        if "Accelerometer" in f:
            df["set"] = acc_set
            acc_set += 1
            acc_df = pd.concat([acc_df, df])

        if "Gyroscope" in f:
            df["set"] = gyr_set
            gyr_set += 1
            gyr_df = pd.concat([gyr_df, df])
            
    acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms")
    gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")   
    
    del acc_df["epoch (ms)"]
    del acc_df["time (01:00)"]      
    del acc_df["elapsed (s)"]
    
    del gyr_df["epoch (ms)"]
    del gyr_df["time (01:00)"]      
    del gyr_df["elapsed (s)"]
    
    return acc_df, gyr_df

# %%
acc_df, gyr_df = read_data_from_files(files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 acc_df, gyr_df = read_data_from_files(files)
#
# NameError: name 'read_data_from_files' is not defined

# %%
files = glob("../../data/raw/MetaMotion/*.csv")

def read_files(files):
    acc_df = pd.DataFrame()
    gyr_df = pd.DataFrame()

    acc_set = 1 
    gyr_set = 1

    for f in files:
    
        participant = f.split("-")[0].replace(data_path, "")
        label = f.split("-")[1]
        category = f.split("-")[2].rstrip("123").rstrip("_MetaWear_2019")

        df = pd.read_csv(f)

        df["participant"] = participant
        df["label"] = label
        df["category"] = category

        if "Accelerometer" in f:
            df["set"] = acc_set
            acc_set += 1
            acc_df = pd.concat([acc_df, df])

        if "Gyroscope" in f:
            df["set"] = gyr_set
            gyr_set += 1
            gyr_df = pd.concat([gyr_df, df])
            
    acc_df.index = pd.to_datetime(acc_df["epoch (ms)"], unit="ms")
    gyr_df.index = pd.to_datetime(gyr_df["epoch (ms)"], unit="ms")   
    
    del acc_df["epoch (ms)"]
    del acc_df["time (01:00)"]      
    del acc_df["elapsed (s)"]
    
    del gyr_df["epoch (ms)"]
    del gyr_df["time (01:00)"]      
    del gyr_df["elapsed (s)"]
    
    return acc_df, gyr_df

acc_df, gyr_df = read_data_from_files(files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[157], line 45
#      41     del gyr_df["elapsed (s)"]
#      43     return acc_df, gyr_df
# ---> 45 acc_df, gyr_df = read_data_from_files(files)
#
# NameError: name 'read_data_from_files' is not defined

# %%
acc_df, gyr_df = read_files(files)

# %%
gyr_df
# Out:
#                          x-axis (deg/s)  y-axis (deg/s)  z-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:10:08.351           0.122          -5.488          -3.841
# 2019-01-11 15:10:08.391           2.195          -9.695          -0.610
# 2019-01-11 15:10:08.431           2.622          -8.110          -4.024
# 2019-01-11 15:10:08.471           1.951          -4.695          -4.634
# 2019-01-11 15:10:08.511           1.524          -2.561          -2.500
# ...                                 ...             ...             ...
# 2019-01-16 19:14:23.314          -1.707          -0.671           1.585
# 2019-01-16 19:14:23.354           0.915           0.305           2.988
# 2019-01-16 19:14:23.394           5.854          -2.561           1.463
# 2019-01-16 19:14:23.434           4.268           0.549          -0.305
# 2019-01-16 19:14:23.474          -1.098           1.768          -0.122
#
#                         participant  label category  set
# epoch (ms)
# 2019-01-11 15:10:08.351           A  bench    heavy    1
# 2019-01-11 15:10:08.391           A  bench    heavy    1
# 2019-01-11 15:10:08.431           A  bench    heavy    1
# 2019-01-11 15:10:08.471           A  bench    heavy    1
# 2019-01-11 15:10:08.511           A  bench    heavy    1
# ...                             ...    ...      ...  ...
# 2019-01-16 19:14:23.314           E  squat    heavy   93
# 2019-01-16 19:14:23.354           E  squat    heavy   93
# 2019-01-16 19:14:23.394           E  squat    heavy   93
# 2019-01-16 19:14:23.434           E  squat    heavy   93
# 2019-01-16 19:14:23.474           E  squat    heavy   93
#
# [47218 rows x 7 columns]

# %%
acc_df
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g) participant  \
# epoch (ms)
# 2019-01-11 15:10:08.431       0.010       0.964      -0.087           A
# 2019-01-11 15:10:08.511       0.000       0.961      -0.069           A
# 2019-01-11 15:10:08.591       0.001       0.974      -0.087           A
# 2019-01-11 15:10:08.671      -0.012       0.971      -0.084           A
# 2019-01-11 15:10:08.751      -0.013       0.954      -0.094           A
# ...                             ...         ...         ...         ...
# 2019-01-16 19:14:23.089       0.012       0.596       0.815           E
# 2019-01-16 19:14:23.169       0.009       0.528       0.821           E
# 2019-01-16 19:14:23.249       0.015       0.554       0.746           E
# 2019-01-16 19:14:23.329       0.006       0.574       0.824           E
# 2019-01-16 19:14:23.409       0.015       0.588       0.826           E
#
#                          label category  set
# epoch (ms)
# 2019-01-11 15:10:08.431  bench    heavy    1
# 2019-01-11 15:10:08.511  bench    heavy    1
# 2019-01-11 15:10:08.591  bench    heavy    1
# 2019-01-11 15:10:08.671  bench    heavy    1
# 2019-01-11 15:10:08.751  bench    heavy    1
# ...                        ...      ...  ...
# 2019-01-16 19:14:23.089  squat    heavy   94
# 2019-01-16 19:14:23.169  squat    heavy   94
# 2019-01-16 19:14:23.249  squat    heavy   94
# 2019-01-16 19:14:23.329  squat    heavy   94
# 2019-01-16 19:14:23.409  squat    heavy   94
#
# [23578 rows x 7 columns]

# %%
pd.concat([acc_df, gyr_df], axis=1)
# Out:
# <ipython-input-161-5759e21e66bf>:1: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   pd.concat([acc_df, gyr_df], axis=1)
#                          x-axis (g)  y-axis (g)  z-axis (g) participant label  \
# epoch (ms)
# 2019-01-11 15:08:04.950         NaN         NaN         NaN         NaN   NaN
# 2019-01-11 15:08:04.990         NaN         NaN         NaN         NaN   NaN
# 2019-01-11 15:08:05.030         NaN         NaN         NaN         NaN   NaN
# 2019-01-11 15:08:05.070         NaN         NaN         NaN         NaN   NaN
# 2019-01-11 15:08:05.110         NaN         NaN         NaN         NaN   NaN
# ...                             ...         ...         ...         ...   ...
# 2019-01-20 17:35:13.382      -0.060      -1.021      -0.058           E   row
# 2019-01-20 17:35:13.462      -0.035      -1.037      -0.026           E   row
# 2019-01-20 17:35:13.542      -0.045      -1.029      -0.033           E   row
# 2019-01-20 17:35:13.622      -0.039      -1.027      -0.039           E   row
# 2019-01-20 17:35:13.702      -0.049      -1.031      -0.049           E   row
#
#                         category   set  x-axis (deg/s)  y-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:08:04.950      NaN   NaN         -10.671          -1.524
# 2019-01-11 15:08:04.990      NaN   NaN          -8.720          -2.073
# 2019-01-11 15:08:05.030      NaN   NaN           0.488          -3.537
# 2019-01-11 15:08:05.070      NaN   NaN           0.244          -5.854
# 2019-01-11 15:08:05.110      NaN   NaN          -0.915           0.061
# ...                          ...   ...             ...             ...
# 2019-01-20 17:35:13.382   medium  92.0             NaN             NaN
# 2019-01-20 17:35:13.462   medium  92.0             NaN             NaN
# 2019-01-20 17:35:13.542   medium  92.0             NaN             NaN
# 2019-01-20 17:35:13.622   medium  92.0             NaN             NaN
# 2019-01-20 17:35:13.702   medium  92.0             NaN             NaN
#
#                          z-axis (deg/s) participant  label category   set
# epoch (ms)
# 2019-01-11 15:08:04.950           5.976           B  bench    heavy  30.0
# 2019-01-11 15:08:04.990           3.171           B  bench    heavy  30.0
# 2019-01-11 15:08:05.030          -4.146           B  bench    heavy  30.0
# 2019-01-11 15:08:05.070           3.537           B  bench    heavy  30.0
# 2019-01-11 15:08:05.110          -2.805           B  bench    heavy  30.0
# ...                                 ...         ...    ...      ...   ...
# 2019-01-20 17:35:13.382             NaN         NaN    NaN      NaN   NaN
# 2019-01-20 17:35:13.462             NaN         NaN    NaN      NaN   NaN
# 2019-01-20 17:35:13.542             NaN         NaN    NaN      NaN   NaN
# 2019-01-20 17:35:13.622             NaN         NaN    NaN      NaN   NaN
# 2019-01-20 17:35:13.702             NaN         NaN    NaN      NaN   NaN
#
# [69677 rows x 14 columns]

# %%
pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1)
# Out:
# <ipython-input-162-6203e873d15f>:1: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1)
#                          x-axis (g)  y-axis (g)  z-axis (g)  x-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:08:04.950         NaN         NaN         NaN         -10.671
# 2019-01-11 15:08:04.990         NaN         NaN         NaN          -8.720
# 2019-01-11 15:08:05.030         NaN         NaN         NaN           0.488
# 2019-01-11 15:08:05.070         NaN         NaN         NaN           0.244
# 2019-01-11 15:08:05.110         NaN         NaN         NaN          -0.915
# ...                             ...         ...         ...             ...
# 2019-01-20 17:35:13.382      -0.060      -1.021      -0.058             NaN
# 2019-01-20 17:35:13.462      -0.035      -1.037      -0.026             NaN
# 2019-01-20 17:35:13.542      -0.045      -1.029      -0.033             NaN
# 2019-01-20 17:35:13.622      -0.039      -1.027      -0.039             NaN
# 2019-01-20 17:35:13.702      -0.049      -1.031      -0.049             NaN
#
#                          y-axis (deg/s)  z-axis (deg/s) participant  label  \
# epoch (ms)
# 2019-01-11 15:08:04.950          -1.524           5.976           B  bench
# 2019-01-11 15:08:04.990          -2.073           3.171           B  bench
# 2019-01-11 15:08:05.030          -3.537          -4.146           B  bench
# 2019-01-11 15:08:05.070          -5.854           3.537           B  bench
# 2019-01-11 15:08:05.110           0.061          -2.805           B  bench
# ...                                 ...             ...         ...    ...
# 2019-01-20 17:35:13.382             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.462             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.542             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.622             NaN             NaN         NaN    NaN
# 2019-01-20 17:35:13.702             NaN             NaN         NaN    NaN
#
#                         category   set
# epoch (ms)
# 2019-01-11 15:08:04.950    heavy  30.0
# 2019-01-11 15:08:04.990    heavy  30.0
# 2019-01-11 15:08:05.030    heavy  30.0
# 2019-01-11 15:08:05.070    heavy  30.0
# 2019-01-11 15:08:05.110    heavy  30.0
# ...                          ...   ...
# 2019-01-20 17:35:13.382      NaN   NaN
# 2019-01-20 17:35:13.462      NaN   NaN
# 2019-01-20 17:35:13.542      NaN   NaN
# 2019-01-20 17:35:13.622      NaN   NaN
# 2019-01-20 17:35:13.702      NaN   NaN
#
# [69677 rows x 10 columns]

# %%
data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1)
# Out:
# <ipython-input-163-0ee025073f40>:1: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1)

# %%
data_merged.dropna()
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g)  x-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:10:08.431       0.010       0.964      -0.087           2.622
# 2019-01-11 15:10:08.511       0.000       0.961      -0.069           1.524
# 2019-01-11 15:10:08.591       0.001       0.974      -0.087           1.707
# 2019-01-11 15:10:08.671      -0.012       0.971      -0.084           2.683
# 2019-01-11 15:10:08.751      -0.013       0.954      -0.094           1.524
# ...                             ...         ...         ...             ...
# 2019-01-15 19:04:25.561       0.369       0.591       0.761          11.220
# 2019-01-15 19:04:25.641       0.387       0.566       0.776           3.963
# 2019-01-15 19:04:25.721       0.361       0.574       0.680          15.305
# 2019-01-15 19:04:25.801       0.353       0.583       0.635          30.366
# 2019-01-15 19:04:25.881       0.359       0.605       0.678          14.756
#
#                          y-axis (deg/s)  z-axis (deg/s) participant  label  \
# epoch (ms)
# 2019-01-11 15:10:08.431          -8.110          -4.024           A  bench
# 2019-01-11 15:10:08.511          -2.561          -2.500           A  bench
# 2019-01-11 15:10:08.591          -5.366           0.915           A  bench
# 2019-01-11 15:10:08.671          -4.146          -1.220           A  bench
# 2019-01-11 15:10:08.751           0.610          -3.171           A  bench
# ...                                 ...             ...         ...    ...
# 2019-01-15 19:04:25.561          -5.061          -5.061           A  squat
# 2019-01-15 19:04:25.641          -2.988          -0.793           A  squat
# 2019-01-15 19:04:25.721          -3.293          -0.671           A  squat
# 2019-01-15 19:04:25.801          -0.122          -4.573           A  squat
# 2019-01-15 19:04:25.881          -6.585          -2.378           A  squat
#
#                         category   set
# epoch (ms)
# 2019-01-11 15:10:08.431    heavy   1.0
# 2019-01-11 15:10:08.511    heavy   1.0
# 2019-01-11 15:10:08.591    heavy   1.0
# 2019-01-11 15:10:08.671    heavy   1.0
# 2019-01-11 15:10:08.751    heavy   1.0
# ...                          ...   ...
# 2019-01-15 19:04:25.561    heavy  24.0
# 2019-01-15 19:04:25.641    heavy  24.0
# 2019-01-15 19:04:25.721    heavy  24.0
# 2019-01-15 19:04:25.801    heavy  24.0
# 2019-01-15 19:04:25.881    heavy  24.0
#
# [1119 rows x 10 columns]

# %%
data_merged.columns = [
    "acc_x", 
    "acc_y", 
    "acc_z", 
    "gyr_x", 
    "gyr_y", 
    "gyr_z", 
    "label", 
    "category", 
    "participant",
    "set"]

# %%
data_merged
# Out:
#                          acc_x  acc_y  acc_z   gyr_x  gyr_y  gyr_z label  \
# epoch (ms)
# 2019-01-11 15:08:04.950    NaN    NaN    NaN -10.671 -1.524  5.976     B
# 2019-01-11 15:08:04.990    NaN    NaN    NaN  -8.720 -2.073  3.171     B
# 2019-01-11 15:08:05.030    NaN    NaN    NaN   0.488 -3.537 -4.146     B
# 2019-01-11 15:08:05.070    NaN    NaN    NaN   0.244 -5.854  3.537     B
# 2019-01-11 15:08:05.110    NaN    NaN    NaN  -0.915  0.061 -2.805     B
# ...                        ...    ...    ...     ...    ...    ...   ...
# 2019-01-20 17:35:13.382 -0.060 -1.021 -0.058     NaN    NaN    NaN   NaN
# 2019-01-20 17:35:13.462 -0.035 -1.037 -0.026     NaN    NaN    NaN   NaN
# 2019-01-20 17:35:13.542 -0.045 -1.029 -0.033     NaN    NaN    NaN   NaN
# 2019-01-20 17:35:13.622 -0.039 -1.027 -0.039     NaN    NaN    NaN   NaN
# 2019-01-20 17:35:13.702 -0.049 -1.031 -0.049     NaN    NaN    NaN   NaN
#
#                         category participant   set
# epoch (ms)
# 2019-01-11 15:08:04.950    bench       heavy  30.0
# 2019-01-11 15:08:04.990    bench       heavy  30.0
# 2019-01-11 15:08:05.030    bench       heavy  30.0
# 2019-01-11 15:08:05.070    bench       heavy  30.0
# 2019-01-11 15:08:05.110    bench       heavy  30.0
# ...                          ...         ...   ...
# 2019-01-20 17:35:13.382      NaN         NaN   NaN
# 2019-01-20 17:35:13.462      NaN         NaN   NaN
# 2019-01-20 17:35:13.542      NaN         NaN   NaN
# 2019-01-20 17:35:13.622      NaN         NaN   NaN
# 2019-01-20 17:35:13.702      NaN         NaN   NaN
#
# [69677 rows x 10 columns]

# %%
data_merged[:100].resample(rule="S")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 data_merged[:100].resample(rule="S")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_merged[:100].resample(rule="S").mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 data_merged[:100].resample(rule="S").mean()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1) 

data_merged.columns = [
    "acc_x", 
    "acc_y", 
    "acc_z", 
    "gyr_x", 
    "gyr_y", 
    "gyr_z", 
    "label", 
    "category", 
    "participant",
    "set"
    ] 

# --------------------------------------------------------------
# Resample data (frequency conversion)
# --------------------------------------------------------------

# Accelerometer:    12.500HZ
# Gyroscope:        25.000Hz

data_merged[:100].resample(rule="S").mean()
# Out:
# <ipython-input-169-6329cfad664a>:1: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[169], line 23
#       3 data_merged.columns = [
#       4     "acc_x",
#       5     "acc_y",
#    (...)     13     "set"
#      14     ]
#      16 # --------------------------------------------------------------
#      17 # Resample data (frequency conversion)
#      18 # --------------------------------------------------------------
#      19
#      20 # Accelerometer:    12.500HZ
#      21 # Gyroscope:        25.000Hz
# ---> 23 data_merged[:100].resample(rule="S").mean()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1) 

data_merged.columns = [
    "acc_x", 
    "acc_y", 
    "acc_z", 
    "gyr_x", 
    "gyr_y", 
    "gyr_z", 
    "label", 
    "category", 
    "participant",
    "set"]
# Out:
# <ipython-input-170-09c4f7e4ef37>:1: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1)

# %%
data_merged[:100].resample(rule="S").mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 data_merged[:100].resample(rule="S").mean()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_resampled = data_merged.resample(rule="S").mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 data_resampled = data_merged.resample(rule="S").mean()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_merged[:100].resample("S").mean() # Resample to 10Hz (100ms intervals)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[173], line 1
# ----> 1 data_merged[:100].resample("S").mean() # Resample to 10Hz (100ms intervals)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_merged[:100].resample(rule="S").mean() # Resample to 10Hz (100ms intervals)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 data_merged[:100].resample(rule="S").mean() # Resample to 10Hz (100ms intervals)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1) 

data_merged.columns = [
    "acc_x", 
    "acc_y", 
    "acc_z", 
    "gyr_x", 
    "gyr_y", 
    "gyr_z", 
    "label", 
    "category", 
    "participant",
    "set"] 

# Ensure the index is a DatetimeIndex for resampling
data_merged.index = acc_df.index

# --------------------------------------------------------------
# Resample data (frequency conversion)
# --------------------------------------------------------------

# Accelerometer:    12.500HZ
# Gyroscope:        25.000Hz

data_merged[:100].resample(rule="S").mean()
# Out:
# <ipython-input-175-f5c36ad007da>:1: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[175], line 16
#       3 data_merged.columns = [
#       4     "acc_x",
#       5     "acc_y",
#    (...)     12     "participant",
#      13     "set"]
#      15 # Ensure the index is a DatetimeIndex for resampling
# ---> 16 data_merged.index = acc_df.index
#      18 # --------------------------------------------------------------
#      19 # Resample data (frequency conversion)
#      20 # --------------------------------------------------------------
#      21
#      22 # Accelerometer:    12.500HZ
#      23 # Gyroscope:        25.000Hz
#      25 data_merged[:100].resample(rule="S").mean()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6220, in NDFrame.__setattr__(self, name, value)
#    6218 try:
#    6219     object.__getattribute__(self, name)
# -> 6220     return object.__setattr__(self, name, value)
#    6221 except AttributeError:
#    6222     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:766, in NDFrame._set_axis(self, axis, labels)
#     761 """
#     762 This is called from the cython code when we set the `index` attribute
#     763 directly, e.g. `series.index = [1, 2, 3]`.
#     764 """
#     765 labels = ensure_index(labels)
# --> 766 self._mgr.set_axis(axis, labels)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:273, in BaseBlockManager.set_axis(self, axis, new_labels)
#     271 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     272     # Caller is responsible for ensuring we have an Index object.
# --> 273     self._validate_set_axis(axis, new_labels)
#     274     self.axes[axis] = new_labels
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:288, in BaseBlockManager._validate_set_axis(self, axis, new_labels)
#     285     pass
#     287 elif new_len != old_len:
# --> 288     raise ValueError(
#     289         f"Length mismatch: Expected axis has {old_len} elements, new "
#     290         f"values have {new_len} elements"
#     291     )
#
# ValueError: Length mismatch: Expected axis has 69677 elements, new values have 23578 elements

# %%
data_merged.index = acc_df.index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 data_merged.index = acc_df.index
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6220, in NDFrame.__setattr__(self, name, value)
#    6218 try:
#    6219     object.__getattribute__(self, name)
# -> 6220     return object.__setattr__(self, name, value)
#    6221 except AttributeError:
#    6222     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:766, in NDFrame._set_axis(self, axis, labels)
#     761 """
#     762 This is called from the cython code when we set the `index` attribute
#     763 directly, e.g. `series.index = [1, 2, 3]`.
#     764 """
#     765 labels = ensure_index(labels)
# --> 766 self._mgr.set_axis(axis, labels)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:273, in BaseBlockManager.set_axis(self, axis, new_labels)
#     271 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     272     # Caller is responsible for ensuring we have an Index object.
# --> 273     self._validate_set_axis(axis, new_labels)
#     274     self.axes[axis] = new_labels
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:288, in BaseBlockManager._validate_set_axis(self, axis, new_labels)
#     285     pass
#     287 elif new_len != old_len:
# --> 288     raise ValueError(
#     289         f"Length mismatch: Expected axis has {old_len} elements, new "
#     290         f"values have {new_len} elements"
#     291     )
#
# ValueError: Length mismatch: Expected axis has 69677 elements, new values have 23578 elements

# %%
data_merged[:100].resample(rule="S").mean() # Resample to 10Hz (100ms intervals)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 data_merged[:100].resample(rule="S").mean() # Resample to 10Hz (100ms intervals)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1) 

data_merged.columns = [
    "acc_x", 
    "acc_y", 
    "acc_z", 
    "gyr_x", 
    "gyr_y", 
    "gyr_z", 
    "label", 
    "category", 
    "participant",
    "set"] 



# --------------------------------------------------------------
# Resample data (frequency conversion)
# --------------------------------------------------------------

# Accelerometer:    12.500HZ
# Gyroscope:        25.000Hz

data_merged[:100].resample(rule="S").mean()
# Out:
# <ipython-input-178-351519b24b9a>:1: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[178], line 24
#       3 data_merged.columns = [
#       4     "acc_x",
#       5     "acc_y",
#    (...)     12     "participant",
#      13     "set"]
#      17 # --------------------------------------------------------------
#      18 # Resample data (frequency conversion)
#      19 # --------------------------------------------------------------
#      20
#      21 # Accelerometer:    12.500HZ
#      22 # Gyroscope:        25.000Hz
# ---> 24 data_merged[:100].resample(rule="S").mean()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1) 

data_merged.columns = [
    "acc_x", 
    "acc_y", 
    "acc_z", 
    "gyr_x", 
    "gyr_y", 
    "gyr_z", 
    "label", 
    "category", 
    "participant",
    "set"]
# Out:
# <ipython-input-179-09c4f7e4ef37>:1: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1)

# %%
data_merged[:100].resample(rule="S")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[180], line 1
# ----> 1 data_merged[:100].resample(rule="S")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_merged.resample(rule="S").mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'S'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 data_merged.resample(rule="S").mean()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: S. Failed to parse with error message: ValueError("Invalid frequency: S. Failed to parse with error message: KeyError('S'). Did you mean s?") Did you mean s?

# %%
data_resampled = data_merged.resample(rule="200ms").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 data_resampled = data_merged.resample(rule="200ms").mean()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:1532, in Resampler.mean(self, numeric_only)
#    1480 @final
#    1481 def mean(
#    1482     self,
#    1483     numeric_only: bool = False,
#    1484 ):
#    1485     """
#    1486     Compute mean of groups, excluding missing values.
#    1487
#    (...)   1530     Freq: MS, dtype: float64
#    1531     """
# -> 1532     return self._downsample("mean", numeric_only=numeric_only)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2102, in DatetimeIndexResampler._downsample(self, how, **kwargs)
#    2098     return obj
#    2100 # we are downsampling
#    2101 # we want to call the actual grouper method here
# -> 2102 result = obj.groupby(self._grouper).aggregate(how, **kwargs)
#    2103 return self._wrap_result(result)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:291, in Apply.agg(self)
#     288 func = self.func
#     290 if isinstance(func, str):
# --> 291     return self.apply_str()
#     293 if is_dict_like(func):
#     294     return self.agg_dict_like()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:701, in Apply.apply_str(self)
#     697     if "axis" in arg_names and not isinstance(
#     698         obj, (SeriesGroupBy, DataFrameGroupBy)
#     699     ):
#     700         self.kwargs["axis"] = self.axis
# --> 701 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:792, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     790 f = getattr(obj, func)
#     791 if callable(f):
# --> 792     return f(*args, **kwargs)
#     794 # people may aggregate on a non-callable attribute
#     795 # but don't let them think they can pass args to it
#     796 assert len(args) == 0
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1646, in BlockManager.grouped_reduce(self, func)
#    1644             result_blocks = extend_blocks(applied, result_blocks)
#    1645     else:
# -> 1646         applied = blk.apply(func)
#    1647         result_blocks = extend_blocks(applied, result_blocks)
#    1649 if len(result_blocks) == 0:
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\base.py:2807, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2793 if isinstance(self.dtype, StringDtype):
#    2794     # StringArray
#    2795     if op.how in [
#    2796         "prod",
#    2797         "mean",
#    (...)   2805         "kurt",
#    2806     ]:
# -> 2807         raise TypeError(
#    2808             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2809         )
#    2810     if op.how not in ["any", "all"]:
#    2811         # Fail early to avoid conversion to object
#    2812         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %%
data_resampled = data_merged[:1000].resample(rule="200ms").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 data_resampled = data_merged[:1000].resample(rule="200ms").mean()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:1532, in Resampler.mean(self, numeric_only)
#    1480 @final
#    1481 def mean(
#    1482     self,
#    1483     numeric_only: bool = False,
#    1484 ):
#    1485     """
#    1486     Compute mean of groups, excluding missing values.
#    1487
#    (...)   1530     Freq: MS, dtype: float64
#    1531     """
# -> 1532     return self._downsample("mean", numeric_only=numeric_only)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2102, in DatetimeIndexResampler._downsample(self, how, **kwargs)
#    2098     return obj
#    2100 # we are downsampling
#    2101 # we want to call the actual grouper method here
# -> 2102 result = obj.groupby(self._grouper).aggregate(how, **kwargs)
#    2103 return self._wrap_result(result)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:291, in Apply.agg(self)
#     288 func = self.func
#     290 if isinstance(func, str):
# --> 291     return self.apply_str()
#     293 if is_dict_like(func):
#     294     return self.agg_dict_like()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:701, in Apply.apply_str(self)
#     697     if "axis" in arg_names and not isinstance(
#     698         obj, (SeriesGroupBy, DataFrameGroupBy)
#     699     ):
#     700         self.kwargs["axis"] = self.axis
# --> 701 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:792, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     790 f = getattr(obj, func)
#     791 if callable(f):
# --> 792     return f(*args, **kwargs)
#     794 # people may aggregate on a non-callable attribute
#     795 # but don't let them think they can pass args to it
#     796 assert len(args) == 0
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1646, in BlockManager.grouped_reduce(self, func)
#    1644             result_blocks = extend_blocks(applied, result_blocks)
#    1645     else:
# -> 1646         applied = blk.apply(func)
#    1647         result_blocks = extend_blocks(applied, result_blocks)
#    1649 if len(result_blocks) == 0:
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\base.py:2807, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2793 if isinstance(self.dtype, StringDtype):
#    2794     # StringArray
#    2795     if op.how in [
#    2796         "prod",
#    2797         "mean",
#    (...)   2805         "kurt",
#    2806     ]:
# -> 2807         raise TypeError(
#    2808             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2809         )
#    2810     if op.how not in ["any", "all"]:
#    2811         # Fail early to avoid conversion to object
#    2812         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %%
sampling = {  "acc_x", 
    "acc_y", 
    "acc_z", 
    "gyr_x", 
    "gyr_y", 
    "gyr_z", 
    "label", 
    "category", 
    "participant",
    "set"}

# %%
sampling = {  "acc_x": "mean", 
    "acc_y": "mean", 
    "acc_z": "mean", 
    "gyr_x": "mean", 
    "gyr_y": "mean", 
    "gyr_z": "mean", 
    "label": "last", 
    "category": "last", 
    "participant": "last",
    "set": "last",
    }

# %%
data_resampled = data_merged[:1000].resample(rule="200ms").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 data_resampled = data_merged[:1000].resample(rule="200ms").mean()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:1532, in Resampler.mean(self, numeric_only)
#    1480 @final
#    1481 def mean(
#    1482     self,
#    1483     numeric_only: bool = False,
#    1484 ):
#    1485     """
#    1486     Compute mean of groups, excluding missing values.
#    1487
#    (...)   1530     Freq: MS, dtype: float64
#    1531     """
# -> 1532     return self._downsample("mean", numeric_only=numeric_only)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2102, in DatetimeIndexResampler._downsample(self, how, **kwargs)
#    2098     return obj
#    2100 # we are downsampling
#    2101 # we want to call the actual grouper method here
# -> 2102 result = obj.groupby(self._grouper).aggregate(how, **kwargs)
#    2103 return self._wrap_result(result)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:291, in Apply.agg(self)
#     288 func = self.func
#     290 if isinstance(func, str):
# --> 291     return self.apply_str()
#     293 if is_dict_like(func):
#     294     return self.agg_dict_like()
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:701, in Apply.apply_str(self)
#     697     if "axis" in arg_names and not isinstance(
#     698         obj, (SeriesGroupBy, DataFrameGroupBy)
#     699     ):
#     700         self.kwargs["axis"] = self.axis
# --> 701 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:792, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     790 f = getattr(obj, func)
#     791 if callable(f):
# --> 792     return f(*args, **kwargs)
#     794 # people may aggregate on a non-callable attribute
#     795 # but don't let them think they can pass args to it
#     796 assert len(args) == 0
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1646, in BlockManager.grouped_reduce(self, func)
#    1644             result_blocks = extend_blocks(applied, result_blocks)
#    1645     else:
# -> 1646         applied = blk.apply(func)
#    1647         result_blocks = extend_blocks(applied, result_blocks)
#    1649 if len(result_blocks) == 0:
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File c:\Users\folas\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\base.py:2807, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2793 if isinstance(self.dtype, StringDtype):
#    2794     # StringArray
#    2795     if op.how in [
#    2796         "prod",
#    2797         "mean",
#    (...)   2805         "kurt",
#    2806     ]:
# -> 2807         raise TypeError(
#    2808             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2809         )
#    2810     if op.how not in ["any", "all"]:
#    2811         # Fail early to avoid conversion to object
#    2812         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %%
data_resampled = data_merged.resample(rule="200ms").apply(sampling)

# %%
data_merged.resample(rule="200ms").apply(sampling)
# Out:
#                             acc_x     acc_y     acc_z   gyr_x   gyr_y   gyr_z  \
# epoch (ms)
# 2019-01-11 15:08:04.800       NaN       NaN       NaN -9.6955 -1.7985  4.5735
# 2019-01-11 15:08:05.000       NaN       NaN       NaN -2.0122 -0.4270 -1.6218
# 2019-01-11 15:08:05.200  0.013500  0.977000 -0.071000 -1.8904  2.4392  0.9388
# 2019-01-11 15:08:05.400 -0.001500  0.970500 -0.079500 -1.6826 -0.8904  2.1708
# 2019-01-11 15:08:05.600  0.001333  0.971667 -0.064333  2.5608 -0.2560 -1.4146
# ...                           ...       ...       ...     ...     ...     ...
# 2019-01-20 17:35:12.800 -0.041000 -1.247000 -0.074667     NaN     NaN     NaN
# 2019-01-20 17:35:13.000 -0.039000 -1.037500 -0.043500     NaN     NaN     NaN
# 2019-01-20 17:35:13.200 -0.050667 -1.009667 -0.042667     NaN     NaN     NaN
# 2019-01-20 17:35:13.400 -0.040000 -1.033000 -0.029500     NaN     NaN     NaN
# 2019-01-20 17:35:13.600 -0.044000 -1.029000 -0.044000     NaN     NaN     NaN
#
#                         label category participant   set
# epoch (ms)
# 2019-01-11 15:08:04.800     B    bench       heavy  30.0
# 2019-01-11 15:08:05.000     B    bench       heavy  30.0
# 2019-01-11 15:08:05.200     B    bench       heavy  30.0
# 2019-01-11 15:08:05.400     B    bench       heavy  30.0
# 2019-01-11 15:08:05.600     B    bench       heavy  30.0
# ...                       ...      ...         ...   ...
# 2019-01-20 17:35:12.800   NaN      NaN         NaN   NaN
# 2019-01-20 17:35:13.000   NaN      NaN         NaN   NaN
# 2019-01-20 17:35:13.200   NaN      NaN         NaN   NaN
# 2019-01-20 17:35:13.400   NaN      NaN         NaN   NaN
# 2019-01-20 17:35:13.600   NaN      NaN         NaN   NaN
#
# [3932145 rows x 10 columns]

# %%
days = [g for n, g in data_merged.groupby(pd.Grouper(freq="D"))]

# %%
data_resampled = pd.concat([df.resample(rule="200ms").apply(sampling).dropna() for df in days])

# %%
data_resampled = pd.concat([df.resample(rule="200ms").apply(sampling).dropna() for df in days])

# %%
data_resampled
# Out:
#                             acc_x     acc_y     acc_z   gyr_x   gyr_y   gyr_z  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.013500  0.977000 -0.071000 -1.8904  2.4392  0.9388
# 2019-01-11 15:08:05.400 -0.001500  0.970500 -0.079500 -1.6826 -0.8904  2.1708
# 2019-01-11 15:08:05.600  0.001333  0.971667 -0.064333  2.5608 -0.2560 -1.4146
# 2019-01-11 15:08:05.800 -0.024000  0.957000 -0.073500  8.0610 -4.5244 -2.0730
# 2019-01-11 15:08:06.000 -0.028000  0.957667 -0.115000  2.4390 -1.5486 -3.6098
# ...                           ...       ...       ...     ...     ...     ...
# 2019-01-20 17:33:27.000 -0.048000 -1.041500 -0.076500  1.4146 -5.6218  0.2926
# 2019-01-20 17:33:27.200 -0.037000 -1.030333 -0.053333 -2.7684 -0.5854  2.2440
# 2019-01-20 17:33:27.400 -0.060000 -1.031000 -0.082000  2.8416 -5.1342 -0.1220
# 2019-01-20 17:33:27.600 -0.038667 -1.025667 -0.044667 -0.2318  0.2562  1.1220
# 2019-01-20 17:33:27.800 -0.044000 -1.034000 -0.059000  1.0980 -4.0240  0.9760
#
#                         label category participant   set
# epoch (ms)
# 2019-01-11 15:08:05.200     B    bench       heavy  30.0
# 2019-01-11 15:08:05.400     B    bench       heavy  30.0
# 2019-01-11 15:08:05.600     B    bench       heavy  30.0
# 2019-01-11 15:08:05.800     B    bench       heavy  30.0
# 2019-01-11 15:08:06.000     B    bench       heavy  30.0
# ...                       ...      ...         ...   ...
# 2019-01-20 17:33:27.000     E      row      medium  90.0
# 2019-01-20 17:33:27.200     E      row      medium  90.0
# 2019-01-20 17:33:27.400     E      row      medium  90.0
# 2019-01-20 17:33:27.600     E      row      medium  90.0
# 2019-01-20 17:33:27.800     E      row      medium  90.0
#
# [9009 rows x 10 columns]

# %%
data_resampled.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 9009 entries, 2019-01-11 15:08:05.200000 to 2019-01-20 17:33:27.800000
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   acc_x        9009 non-null   float64
#  1   acc_y        9009 non-null   float64
#  2   acc_z        9009 non-null   float64
#  3   gyr_x        9009 non-null   float64
#  4   gyr_y        9009 non-null   float64
#  5   gyr_z        9009 non-null   float64
#  6   label        9009 non-null   str
#  7   category     9009 non-null   str
#  8   participant  9009 non-null   str
#  9   set          9009 non-null   float64
# dtypes: float64(7), str(3)
# memory usage: 774.2 KB

# %%
data_resampled["set"] = data_resampled["set"].astype(int)

# %%
data_resampled.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 9009 entries, 2019-01-11 15:08:05.200000 to 2019-01-20 17:33:27.800000
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   acc_x        9009 non-null   float64
#  1   acc_y        9009 non-null   float64
#  2   acc_z        9009 non-null   float64
#  3   gyr_x        9009 non-null   float64
#  4   gyr_y        9009 non-null   float64
#  5   gyr_z        9009 non-null   float64
#  6   label        9009 non-null   str
#  7   category     9009 non-null   str
#  8   participant  9009 non-null   str
#  9   set          9009 non-null   int64
# dtypes: float64(6), int64(1), str(3)
# memory usage: 774.2 KB

# %%
data_resampled.to_pickle("../../data/interim/01_data_processed.pkl")

# %%
data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1) 

data_merged.columns = [
    "acc_x", 
    "acc_y", 
    "acc_z", 
    "gyr_x", 
    "gyr_y", 
    "gyr_z", 
    "participant",
    "label", 
    "category", 
    "set"]
# Out:
# <ipython-input-197-5dd8f7745e94>:1: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   data_merged = pd.concat([acc_df.iloc[:,:3], gyr_df], axis=1)

# %%
sampling = {  "acc_x": "mean", 
    "acc_y": "mean", 
    "acc_z": "mean", 
    "gyr_x": "mean", 
    "gyr_y": "mean", 
    "gyr_z": "mean", 
    "participant": "last",
    "label": "last", 
    "category": "last", 
    "set": "last",
# Out:
#   Cell In[198], line 10
#     "set": "last",
#                   ^
# SyntaxError: incomplete input

# %%
sampling = {  "acc_x": "mean", 
    "acc_y": "mean", 
    "acc_z": "mean", 
    "gyr_x": "mean", 
    "gyr_y": "mean", 
    "gyr_z": "mean", 
    "participant": "last",
    "label": "last", 
    "category": "last", 
    "set": "last"
    }

# %%
data_merged.resample(rule="200ms").apply(sampling)

#split by day 
days = [g for n, g in data_merged.groupby(pd.Grouper(freq="D"))]
data_resampled = pd.concat([df.resample(rule="200ms").apply(sampling).dropna() for df in days])

data_resampled["set"] = data_resampled["set"].astype(int)
data_resampled.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 9009 entries, 2019-01-11 15:08:05.200000 to 2019-01-20 17:33:27.800000
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   acc_x        9009 non-null   float64
#  1   acc_y        9009 non-null   float64
#  2   acc_z        9009 non-null   float64
#  3   gyr_x        9009 non-null   float64
#  4   gyr_y        9009 non-null   float64
#  5   gyr_z        9009 non-null   float64
#  6   participant  9009 non-null   str
#  7   label        9009 non-null   str
#  8   category     9009 non-null   str
#  9   set          9009 non-null   int64
# dtypes: float64(6), int64(1), str(3)
# memory usage: 774.2 KB

# %%
data_resampled
# Out:
#                             acc_x     acc_y     acc_z   gyr_x   gyr_y   gyr_z  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.013500  0.977000 -0.071000 -1.8904  2.4392  0.9388
# 2019-01-11 15:08:05.400 -0.001500  0.970500 -0.079500 -1.6826 -0.8904  2.1708
# 2019-01-11 15:08:05.600  0.001333  0.971667 -0.064333  2.5608 -0.2560 -1.4146
# 2019-01-11 15:08:05.800 -0.024000  0.957000 -0.073500  8.0610 -4.5244 -2.0730
# 2019-01-11 15:08:06.000 -0.028000  0.957667 -0.115000  2.4390 -1.5486 -3.6098
# ...                           ...       ...       ...     ...     ...     ...
# 2019-01-20 17:33:27.000 -0.048000 -1.041500 -0.076500  1.4146 -5.6218  0.2926
# 2019-01-20 17:33:27.200 -0.037000 -1.030333 -0.053333 -2.7684 -0.5854  2.2440
# 2019-01-20 17:33:27.400 -0.060000 -1.031000 -0.082000  2.8416 -5.1342 -0.1220
# 2019-01-20 17:33:27.600 -0.038667 -1.025667 -0.044667 -0.2318  0.2562  1.1220
# 2019-01-20 17:33:27.800 -0.044000 -1.034000 -0.059000  1.0980 -4.0240  0.9760
#
#                         participant  label category  set
# epoch (ms)
# 2019-01-11 15:08:05.200           B  bench    heavy   30
# 2019-01-11 15:08:05.400           B  bench    heavy   30
# 2019-01-11 15:08:05.600           B  bench    heavy   30
# 2019-01-11 15:08:05.800           B  bench    heavy   30
# 2019-01-11 15:08:06.000           B  bench    heavy   30
# ...                             ...    ...      ...  ...
# 2019-01-20 17:33:27.000           E    row   medium   90
# 2019-01-20 17:33:27.200           E    row   medium   90
# 2019-01-20 17:33:27.400           E    row   medium   90
# 2019-01-20 17:33:27.600           E    row   medium   90
# 2019-01-20 17:33:27.800           E    row   medium   90
#
# [9009 rows x 10 columns]

# %%
data_resampled.to_pickle("../../data/interim/01_data_processed.pkl")
